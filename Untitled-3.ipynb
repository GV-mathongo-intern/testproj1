# %%
import pandas as pd

# %%
import json
with open('strapi-admin-panel.sections.json') as outf:
    d=json.load(outf)

# %%
df1=pd.DataFrame.from_dict(d)
df1.head()
# Out:
#                                     _id sectionType  \
# 0  {'$oid': '60e2fb3f66f9ce3f243b4eee'}      normal
# 1  {'$oid': '60e2fbc266f9ce3f243b5638'}      normal
# 2  {'$oid': '60cefba7185d7a32fa319f83'}         NaN
# 3  {'$oid': '60d3035faf049203d85367bb'}         NaN
# 4  {'$oid': '60e56817499d1e49588fa6dc'}       bonus
#
#                                            questions  \
# 0  [{'$oid': '60e2fb3e66f9ce3f243b4eba'}, {'$oid'...
# 1  [{'$oid': '60e2fbc266f9ce3f243b5604'}, {'$oid'...
# 2  [{'$oid': '60cefba7185d7a32fa319ef4'}, {'$oid'...
# 3  [{'$oid': '60d3035faf049203d8536795'}, {'$oid'...
# 4  [{'$oid': '60e56817499d1e49588fa6af'}, {'$oid'...
#
#                         title  \
# 0      Mathematics Category 3
# 1      Mathematics Category 3
# 2         Chemistry Numerical
# 3  Mathematics Single Correct
# 4             Chemistry Bonus
#
#                                         description  \
# 0             Mathematics Mock 3 Paper 1 Category 3
# ...

# %%
df1['markingscheme1']=df1['markingScheme'].apply(lambda x:x.get('$oid'))
df1.drop('markingScheme',axis=1,inplace=True)
df1.head()
# Out:
#                                     _id sectionType  \
# 0  {'$oid': '60e2fb3f66f9ce3f243b4eee'}      normal
# 1  {'$oid': '60e2fbc266f9ce3f243b5638'}      normal
# 2  {'$oid': '60cefba7185d7a32fa319f83'}         NaN
# 3  {'$oid': '60d3035faf049203d85367bb'}         NaN
# 4  {'$oid': '60e56817499d1e49588fa6dc'}       bonus
#
#                                            questions  \
# 0  [{'$oid': '60e2fb3e66f9ce3f243b4eba'}, {'$oid'...
# 1  [{'$oid': '60e2fbc266f9ce3f243b5604'}, {'$oid'...
# 2  [{'$oid': '60cefba7185d7a32fa319ef4'}, {'$oid'...
# 3  [{'$oid': '60d3035faf049203d8536795'}, {'$oid'...
# 4  [{'$oid': '60e56817499d1e49588fa6af'}, {'$oid'...
#
#                         title  \
# 0      Mathematics Category 3
# 1      Mathematics Category 3
# 2         Chemistry Numerical
# 3  Mathematics Single Correct
# 4             Chemistry Bonus
#
#                                         description  \
# 0             Mathematics Mock 3 Paper 1 Category 3
# ...

# %%
df1.shape
# Out:
# (7094, 13)

# %%
df1.drop(['instruction','__v'],axis=1,inplace=True)

# %%
da=df1[~df1['updatedAt'].isna()]

# %%
da.shape
# Out:
# (4199, 13)

# %%
df1.drop(['updatedAt','updated_by'],axis=1,inplace=True)
df1.head()
# Out:
#                                     _id sectionType  \
# 0  {'$oid': '60e2fb3f66f9ce3f243b4eee'}      normal
# 1  {'$oid': '60e2fbc266f9ce3f243b5638'}      normal
# 2  {'$oid': '60cefba7185d7a32fa319f83'}         NaN
# 3  {'$oid': '60d3035faf049203d85367bb'}         NaN
# 4  {'$oid': '60e56817499d1e49588fa6dc'}       bonus
#
#                                            questions  \
# 0  [{'$oid': '60e2fb3e66f9ce3f243b4eba'}, {'$oid'...
# 1  [{'$oid': '60e2fbc266f9ce3f243b5604'}, {'$oid'...
# 2  [{'$oid': '60cefba7185d7a32fa319ef4'}, {'$oid'...
# 3  [{'$oid': '60d3035faf049203d8536795'}, {'$oid'...
# 4  [{'$oid': '60e56817499d1e49588fa6af'}, {'$oid'...
#
#                         title  \
# 0      Mathematics Category 3
# 1      Mathematics Category 3
# 2         Chemistry Numerical
# 3  Mathematics Single Correct
# 4             Chemistry Bonus
#
#                                         description  \
# 0             Mathematics Mock 3 Paper 1 Category 3
# ...

# %%
df2=df1.query('linkedQuestions.notna() or len(linkedQuestions)!=0 ').head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/collections/__init__.py:941, in ChainMap.__getitem__(self, key)
#     940         pass
# --> 941 return self.__missing__(key)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/collections/__init__.py:933, in ChainMap.__missing__(self, key)
#     932 def __missing__(self, key):
# --> 933     raise KeyError(key)
#
# KeyError: 'len'
#
# ...
