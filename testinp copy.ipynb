# %%
import pandas as pd

# %%
df1_1_1=pd.read_csv('April.csv')

# %%
df1_1_1.head()
# Out:
#       Your registered email id  Your registered mobile number  Percentile
# 0  priyanshujha.pj06@gmail.com                     8668606304   99.197164
# 1      vidhitalwar01@gmail.com                     8273002370   99.003291
# 2      upwordhill987@gmail.com                     9625497741   99.443676
# 3          rs.raag17@gmail.com                     9560806945   99.728357
# 4    maheshbarik2006@gmail.com                     8093378029   99.295775

# %%
df1_1_1=df1_1_1[df1_1_1['Percentile']>=99.5]

# %%
df1_1_1=df1_1_1.reset_index()
df1_1_1.head()
# Out:
#    index       Your registered email id  Your registered mobile number  \
# 0      3            rs.raag17@gmail.com                     9560806945
# 1      7  harshvardhanbagri44@gmail.com                     8168902818
# 2     14   pritishcartoonsbig@gmail.com                     9873420111
# 3     17         arnavmaloo09@gmail.com                     8529649169
# 4     18            ameya7072@gmail.com                     7895646931
#
#    Percentile
# 0   99.728357
# 1   99.517182
# 2   99.513245
# 3   99.522216
# 4   99.553938

# %%
df1_1_1.iloc[:,0]
# Out:
# 0       3
# 1       7
# 2      14
# 3      17
# 4      18
#      ...
# 94    350
# 95    352
# 96    354
# 97    355
# 98    359
# Name: index, Length: 99, dtype: int64

# %%
file = open("list1.txt", "w")
for index in range(len(df1_1_1.iloc[:,0])):
    file.write('{'+"email:'"+str(df1_1_1.iloc[:,1][index]) + "'},")
file.close()

# %%
import json

# %%
with open('strapi-admin-panel.platform_users_aprilpred99_5.json') as outf:
    df1_1=json.load(outf)
df1_1=pd.DataFrame.from_dict(df1_1)
df1_1.head()
# Out:
#                                     _id  \
# 0  {'$oid': '65a9f052c3d3af1fe919a4c5'}
# 1  {'$oid': '6593d648ba0c875fa67a4a3f'}
# 2  {'$oid': '6568b8dc0be0949faa6e1e19'}
# 3  {'$oid': '6558f9c23a1b055d25ff4676'}
# 4  {'$oid': '65673dd583c3399ffb27172a'}
#
#                                             settings  \
# 0  {'emails': True, 'importantEmails': True, 'imp...
# 1  {'emails': True, 'importantEmails': True, 'imp...
# 2  {'emails': True, 'importantEmails': True, 'imp...
# 3  {'emails': True, 'importantEmails': True, 'imp...
# 4  {'emails': False, 'importantEmails': True, 'im...
#
#                                          targetExams FCM_TOKEN  \
# 0  [{'$oid': '605dfcb2f226ac25a8bd5fef'}, {'$oid'...        []
# 1             [{'$oid': '605dfcb2f226ac25a8bd5ff0'}]        []
# 2  [{'$oid': '605dfcb2f226ac25a8bd5ff0'}, {'$oid'...        []
# 3  [{'$oid': '605dfcb2f226ac25a8bd5ff0'}, None, {...        []
# 4  [{'$oid': '605dfcb2f226ac25a8bd5fef'}, {'$oid'...        []
#
# ...

# %%
df1_1['_id']=df1_1['_id'].apply(lambda x:x.get('$oid'))
df1_1.head()
# Out:
#                         _id  \
# 0  65a9f052c3d3af1fe919a4c5
# 1  6593d648ba0c875fa67a4a3f
# 2  6568b8dc0be0949faa6e1e19
# 3  6558f9c23a1b055d25ff4676
# 4  65673dd583c3399ffb27172a
#
#                                             settings  \
# 0  {'emails': True, 'importantEmails': True, 'imp...
# 1  {'emails': True, 'importantEmails': True, 'imp...
# 2  {'emails': True, 'importantEmails': True, 'imp...
# 3  {'emails': True, 'importantEmails': True, 'imp...
# 4  {'emails': False, 'importantEmails': True, 'im...
#
#                                          targetExams FCM_TOKEN  \
# 0  [{'$oid': '605dfcb2f226ac25a8bd5fef'}, {'$oid'...        []
# 1             [{'$oid': '605dfcb2f226ac25a8bd5ff0'}]        []
# 2  [{'$oid': '605dfcb2f226ac25a8bd5ff0'}, {'$oid'...        []
# 3  [{'$oid': '605dfcb2f226ac25a8bd5ff0'}, None, {...        []
# 4  [{'$oid': '605dfcb2f226ac25a8bd5fef'}, {'$oid'...        []
#
#   notificationTopics notifications  isWhatsAppNumber isAllPacksAllowed  \
# ...

# %%
file = open("list1.txt", "w")
for index in range(len(df1_1.iloc[:,0])):
    file.write('{'+"userId:ObjectId('"+str(df1_1.iloc[:,0][index]) + "')},")
file.close()

# %%
with open('strapi-admin-panel.detailed_analyses_aprilpred.json') as outf:
    df2=json.load(outf)
df2=pd.DataFrame.from_dict(df2)
df2.head()
# Out:
#                                     _id                                userId  \
# 0  {'$oid': '62a615351ed36c04de22cae7'}  {'$oid': '62a5b3562f2c8edf02cd8f28'}
# 1  {'$oid': '62af04539011c8495db99872'}  {'$oid': '62a5b3562f2c8edf02cd8f28'}
# 2  {'$oid': '6342cea5c09d95e0e99f9e8b'}  {'$oid': '6342b29ce77795e149e62052'}
# 3  {'$oid': '63627c74ebd62fc378ced962'}  {'$oid': '63542c772ef4ea103afdf799'}
# 4  {'$oid': '63674f2475aa7bc3d7bff510'}  {'$oid': '6342b29ce77795e149e62052'}
#
#                                  testId  notVisited  \
# 0  {'$oid': '629c1fffa267606d24fb7411'}           0
# 1  {'$oid': '629c5b8f8f253e5778bd86a8'}           0
# 2  {'$oid': '62d048869f6e5150d0b4fc0f'}           0
# 3  {'$oid': '62d04863c6a09e2c86a69d09'}          14
# 4  {'$oid': '62d04878cb20fa1bfa8e349a'}           0
#
#                                             subjects  \
# 0  [{'painfulQuestions': [{'$oid': '62a41b00acc3c...
# 1  [{'painfulQuestions': [{'$oid': '62ab299c44ccb...
# ...

# %%
df22=df2

# %%
df22.head()
# Out:
#                                     _id                                userId  \
# 0  {'$oid': '62a615351ed36c04de22cae7'}  {'$oid': '62a5b3562f2c8edf02cd8f28'}
# 1  {'$oid': '62af04539011c8495db99872'}  {'$oid': '62a5b3562f2c8edf02cd8f28'}
# 2  {'$oid': '6342cea5c09d95e0e99f9e8b'}  {'$oid': '6342b29ce77795e149e62052'}
# 3  {'$oid': '63627c74ebd62fc378ced962'}  {'$oid': '63542c772ef4ea103afdf799'}
# 4  {'$oid': '63674f2475aa7bc3d7bff510'}  {'$oid': '6342b29ce77795e149e62052'}
#
#                                  testId  notVisited  \
# 0  {'$oid': '629c1fffa267606d24fb7411'}           0
# 1  {'$oid': '629c5b8f8f253e5778bd86a8'}           0
# 2  {'$oid': '62d048869f6e5150d0b4fc0f'}           0
# 3  {'$oid': '62d04863c6a09e2c86a69d09'}          14
# 4  {'$oid': '62d04878cb20fa1bfa8e349a'}           0
#
#                                             subjects  \
# 0  [{'painfulQuestions': [{'$oid': '62a41b00acc3c...
# 1  [{'painfulQuestions': [{'$oid': '62ab299c44ccb...
# ...

# %%
df22['_id']=df22['_id'].apply(lambda x:x.get('$oid'))
df22['testId']=df22['testId'].apply(lambda x:x.get('$oid'))
df22['userId']=df22['userId'].apply(lambda x:x.get('$oid'))
df22.head()
# Out:
#                         _id                    userId  \
# 0  62a615351ed36c04de22cae7  62a5b3562f2c8edf02cd8f28
# 1  62af04539011c8495db99872  62a5b3562f2c8edf02cd8f28
# 2  6342cea5c09d95e0e99f9e8b  6342b29ce77795e149e62052
# 3  63627c74ebd62fc378ced962  63542c772ef4ea103afdf799
# 4  63674f2475aa7bc3d7bff510  6342b29ce77795e149e62052
#
#                      testId  notVisited  \
# 0  629c1fffa267606d24fb7411           0
# 1  629c5b8f8f253e5778bd86a8           0
# 2  62d048869f6e5150d0b4fc0f           0
# 3  62d04863c6a09e2c86a69d09          14
# 4  62d04878cb20fa1bfa8e349a           0
#
#                                             subjects  \
# 0  [{'painfulQuestions': [{'$oid': '62a41b00acc3c...
# 1  [{'painfulQuestions': [{'$oid': '62ab299c44ccb...
# 2  [{'painfulQuestions': [{'$oid': '617aaa1eef3fe...
# 3  [{'painfulQuestions': [], 'missedConcepts': []...
# 4  [{'painfulQuestions': [{'$oid': '617aa9eaef3fe...
#
#                                            questions  \
# ...

# %%
df2.head()
# Out:
#                         _id                    userId  \
# 0  62a615351ed36c04de22cae7  62a5b3562f2c8edf02cd8f28
# 1  62af04539011c8495db99872  62a5b3562f2c8edf02cd8f28
# 2  6342cea5c09d95e0e99f9e8b  6342b29ce77795e149e62052
# 3  63627c74ebd62fc378ced962  63542c772ef4ea103afdf799
# 4  63674f2475aa7bc3d7bff510  6342b29ce77795e149e62052
#
#                      testId  notVisited  \
# 0  629c1fffa267606d24fb7411           0
# 1  629c5b8f8f253e5778bd86a8           0
# 2  62d048869f6e5150d0b4fc0f           0
# 3  62d04863c6a09e2c86a69d09          14
# 4  62d04878cb20fa1bfa8e349a           0
#
#                                             subjects  \
# 0  [{'painfulQuestions': [{'$oid': '62a41b00acc3c...
# 1  [{'painfulQuestions': [{'$oid': '62ab299c44ccb...
# 2  [{'painfulQuestions': [{'$oid': '617aaa1eef3fe...
# 3  [{'painfulQuestions': [], 'missedConcepts': []...
# 4  [{'painfulQuestions': [{'$oid': '617aa9eaef3fe...
#
#                                            questions  \
# ...

# %%
df1=df2

# %%
df1.head()
# Out:
#                                     _id                                userId  \
# 0  {'$oid': '62a615351ed36c04de22cae7'}  {'$oid': '62a5b3562f2c8edf02cd8f28'}
# 1  {'$oid': '62af04539011c8495db99872'}  {'$oid': '62a5b3562f2c8edf02cd8f28'}
# 2  {'$oid': '6342cea5c09d95e0e99f9e8b'}  {'$oid': '6342b29ce77795e149e62052'}
# 3  {'$oid': '63627c74ebd62fc378ced962'}  {'$oid': '63542c772ef4ea103afdf799'}
# 4  {'$oid': '63674f2475aa7bc3d7bff510'}  {'$oid': '6342b29ce77795e149e62052'}
#
#                                  testId  notVisited  \
# 0  {'$oid': '629c1fffa267606d24fb7411'}           0
# 1  {'$oid': '629c5b8f8f253e5778bd86a8'}           0
# 2  {'$oid': '62d048869f6e5150d0b4fc0f'}           0
# 3  {'$oid': '62d04863c6a09e2c86a69d09'}          14
# 4  {'$oid': '62d04878cb20fa1bfa8e349a'}           0
#
#                                             subjects  \
# 0  [{'painfulQuestions': [{'$oid': '62a41b00acc3c...
# 1  [{'painfulQuestions': [{'$oid': '62ab299c44ccb...
# ...

# %%
df1['_id1']=df1['_id'].apply(lambda x:x.get('$oid'))
df1['testid1']=df1['testId'].apply(lambda x:x.get('$oid'))
df1['userid1']=df1['userId'].apply(lambda x:x.get('$oid'))
df1.head()
# Out:
#                                     _id                                userId  \
# 0  {'$oid': '62a615351ed36c04de22cae7'}  {'$oid': '62a5b3562f2c8edf02cd8f28'}
# 1  {'$oid': '62af04539011c8495db99872'}  {'$oid': '62a5b3562f2c8edf02cd8f28'}
# 2  {'$oid': '6342cea5c09d95e0e99f9e8b'}  {'$oid': '6342b29ce77795e149e62052'}
# 3  {'$oid': '63627c74ebd62fc378ced962'}  {'$oid': '63542c772ef4ea103afdf799'}
# 4  {'$oid': '63674f2475aa7bc3d7bff510'}  {'$oid': '6342b29ce77795e149e62052'}
#
#                                  testId  notVisited  \
# 0  {'$oid': '629c1fffa267606d24fb7411'}           0
# 1  {'$oid': '629c5b8f8f253e5778bd86a8'}           0
# 2  {'$oid': '62d048869f6e5150d0b4fc0f'}           0
# 3  {'$oid': '62d04863c6a09e2c86a69d09'}          14
# 4  {'$oid': '62d04878cb20fa1bfa8e349a'}           0
#
#                                             subjects  \
# 0  [{'painfulQuestions': [{'$oid': '62a41b00acc3c...
# 1  [{'painfulQuestions': [{'$oid': '62ab299c44ccb...
# ...

# %%
df1.drop(['_id','userId','testId'],axis=1,inplace=True)
df1.head()
# Out:
#    notVisited                                           subjects  \
# 0           0  [{'painfulQuestions': [{'$oid': '62a41b00acc3c...
# 1           0  [{'painfulQuestions': [{'$oid': '62ab299c44ccb...
# 2           0  [{'painfulQuestions': [{'$oid': '617aaa1eef3fe...
# 3          14  [{'painfulQuestions': [], 'missedConcepts': []...
# 4           0  [{'painfulQuestions': [{'$oid': '617aa9eaef3fe...
#
#                                            questions  \
# 0  [{'_id': {'$oid': '62a615351ed36c04de22cae9'},...
# 1  [{'_id': {'$oid': '62af04539011c8495db99874'},...
# 2  [{'_id': {'$oid': '6342cea5c09d95e0e99f9e8d'},...
# 3  [{'_id': {'$oid': '63627c74ebd62fc378ced964'},...
# 4  [{'_id': {'$oid': '63674f2475aa7bc3d7bff512'},...
#
#                                           timeTravel  \
# 0  [{'_id': {'$oid': '62a615351ed36c04de22cb02'},...
# 1  [{'_id': {'$oid': '62af04539011c8495db9988d'},...
# 2  [{'_id': {'$oid': '6342cea5c09d95e0e99f9eab'},...
# ...

# %%
df2=pd.DataFrame([tuple(list(d.values()))+(tup._9,) for tup in df1.itertuples() for d in tup.subjects])
df2.columns=list(df1['subjects'][0][0].keys())+['id1']
df2.head()
# Out:
#                                     painfulQuestions  \
# 0  [{'$oid': '62a41b00acc3cedefb5f3471'}, {'$oid'...
# 1  [{'$oid': '62ab299c44ccb43189b68826'}, {'$oid'...
# 2  [{'$oid': '617aaa1eef3fe65ad8e86844'}, {'$oid'...
# 3                                                 []
# 4             [{'$oid': '617aa9eaef3fe65ad8e838b0'}]
#
#                                       missedConcepts  \
# 0  [{'$oid': '62a41b00acc3cedefb5f3462'}, {'$oid'...
# 1  [{'$oid': '62ab299c44ccb43189b68849'}, {'$oid'...
# 2  [{'$oid': '617aaa1eef3fe65ad8e8685d'}, {'$oid'...
# 3                                                 []
# 4  [{'$oid': '617aa9eaef3fe65ad8e83856'}, {'$oid'...
#
#                                     _id                             subjectId  \
# 0  {'$oid': '62a615351ed36c04de22cae8'}  {'$oid': '607018ee404ae53194e73d92'}
# 1  {'$oid': '62af04539011c8495db99873'}  {'$oid': '607018ee404ae53194e73d92'}
# 2  {'$oid': '6342cea5c09d95e0e99f9e8c'}  {'$oid': '607018ee404ae53194e73d92'}
# ...

# %%
df3=df2.drop(['painfulQuestions','missedConcepts','_id','subjectId','timeTaken'],axis=1)
df3.head()
# Out:
#    totalMarkScored  totalAttempted  totalCorrect    accuracy  notVisited  \
# 0             54.0              21            15   71.428571           0
# 1             77.0              23            20   86.956522           0
# 2             65.0              20            17   85.000000           0
# 3             12.0               3             3  100.000000          14
# 4             51.0              24            15   62.500000           0
#
#    easyCorrect  easyIncorrect  easyUnanswered  moderateCorrect  \
# 0            9              3               1                4
# 1           10              1               0                8
# 2           10              1               1                6
# 3            0              0               1                2
# 4            6              2               1                7
#
#    moderateIncorrect  moderateUnanswered  toughCorrect  toughIncorrect  \
# 0                  3                   3             2               0
# ...

# %%
df4=df3.groupby('id1').aggregate('sum')
df4.head()
# Out:
#                           totalMarkScored  totalAttempted  totalCorrect  \
# id1
# 62a615351ed36c04de22cae7             54.0              21            15
# 62af04539011c8495db99872             77.0              23            20
# 6342cea5c09d95e0e99f9e8b             65.0              20            17
# 63627c74ebd62fc378ced962             12.0               3             3
# 63674f2475aa7bc3d7bff510             51.0              24            15
#
#                             accuracy  notVisited  easyCorrect  easyIncorrect  \
# id1
# 62a615351ed36c04de22cae7   71.428571           0            9              3
# 62af04539011c8495db99872   86.956522           0           10              1
# 6342cea5c09d95e0e99f9e8b   85.000000           0           10              1
# 63627c74ebd62fc378ced962  100.000000          14            0              0
# 63674f2475aa7bc3d7bff510   62.500000           0            6              2
#
# ...

# %%
df4['accuracy']=(df4['totalCorrect']/df4['totalAttempted'])*100
df4.head()
# Out:
#                           totalMarkScored  totalAttempted  totalCorrect  \
# id1
# 62a615351ed36c04de22cae7             54.0              21            15
# 62af04539011c8495db99872             77.0              23            20
# 6342cea5c09d95e0e99f9e8b             65.0              20            17
# 63627c74ebd62fc378ced962             12.0               3             3
# 63674f2475aa7bc3d7bff510             51.0              24            15
#
#                             accuracy  notVisited  easyCorrect  easyIncorrect  \
# id1
# 62a615351ed36c04de22cae7   71.428571           0            9              3
# 62af04539011c8495db99872   86.956522           0           10              1
# 6342cea5c09d95e0e99f9e8b   85.000000           0           10              1
# 63627c74ebd62fc378ced962  100.000000          14            0              0
# 63674f2475aa7bc3d7bff510   62.500000           0            6              2
#
# ...

# %%
df4['easyCorrect1']=(df4['easyCorrect']/(df4['easyCorrect']+df4['easyIncorrect']+df4['easyUnanswered']))*100
df4['easyIncorrect1']=(df4['easyIncorrect']/(df4['easyCorrect']+df4['easyIncorrect']+df4['easyUnanswered']))*100
df4['easyUnanswered1']=(df4['easyUnanswered']/(df4['easyCorrect']+df4['easyIncorrect']+df4['easyUnanswered']))*100
df4['moderateCorrect1']=(df4['moderateCorrect']/(df4['moderateCorrect']+df4['moderateIncorrect']+df4['moderateUnanswered']))*100
df4['moderateIncorrect1']=(df4['moderateIncorrect']/(df4['moderateCorrect']+df4['moderateIncorrect']+df4['moderateUnanswered']))*100
df4['moderateUnanswered1']=(df4['moderateUnanswered']/(df4['moderateCorrect']+df4['moderateIncorrect']+df4['moderateUnanswered']))*100
df4['toughCorrect1']=(df4['toughCorrect']/(df4['toughCorrect']+df4['toughIncorrect']+df4['toughUnanswered']))*100
df4['toughIncorrect1']=(df4['toughIncorrect']/(df4['toughCorrect']+df4['toughIncorrect']+df4['toughUnanswered']))*100
df4['toughUnanswered1']=(df4['toughUnanswered']/(df4['toughCorrect']+df4['toughIncorrect']+df4['toughUnanswered']))*100
df4.head()
# Out:
#                           totalMarkScored  totalAttempted  totalCorrect  \
# id1
# 62a615351ed36c04de22cae7             54.0              21            15
# 62af04539011c8495db99872             77.0              23            20
# 6342cea5c09d95e0e99f9e8b             65.0              20            17
# 63627c74ebd62fc378ced962             12.0               3             3
# 63674f2475aa7bc3d7bff510             51.0              24            15
#
#                             accuracy  notVisited  easyCorrect  easyIncorrect  \
# id1
# 62a615351ed36c04de22cae7   71.428571           0            9              3
# 62af04539011c8495db99872   86.956522           0           10              1
# 6342cea5c09d95e0e99f9e8b   85.000000           0           10              1
# 63627c74ebd62fc378ced962  100.000000          14            0              0
# 63674f2475aa7bc3d7bff510   62.500000           0            6              2
#
# ...

# %%
df4['notVisited1']=(df4['notVisited']/(df4['totalCorrect']+df4['easyIncorrect']+df4['easyUnanswered']+df4['moderateIncorrect']+df4['moderateUnanswered']+df4['toughIncorrect']+df4['toughUnanswered']+df4['notVisited']))*100
df4['totalAttempted1']=(df4['totalAttempted']/(df4['totalCorrect']+df4['easyIncorrect']+df4['easyUnanswered']+df4['moderateIncorrect']+df4['moderateUnanswered']+df4['toughIncorrect']+df4['toughUnanswered']+df4['notVisited']))*100
df4['totalCorrect1']=(df4['totalCorrect']/(df4['totalCorrect']+df4['easyIncorrect']+df4['easyUnanswered']+df4['moderateIncorrect']+df4['moderateUnanswered']+df4['toughIncorrect']+df4['toughUnanswered']+df4['notVisited']))*100
df4.head()
# Out:
#                           totalMarkScored  totalAttempted  totalCorrect  \
# id1
# 62a615351ed36c04de22cae7             54.0              21            15
# 62af04539011c8495db99872             77.0              23            20
# 6342cea5c09d95e0e99f9e8b             65.0              20            17
# 63627c74ebd62fc378ced962             12.0               3             3
# 63674f2475aa7bc3d7bff510             51.0              24            15
#
#                             accuracy  notVisited  easyCorrect  easyIncorrect  \
# id1
# 62a615351ed36c04de22cae7   71.428571           0            9              3
# 62af04539011c8495db99872   86.956522           0           10              1
# 6342cea5c09d95e0e99f9e8b   85.000000           0           10              1
# 63627c74ebd62fc378ced962  100.000000          14            0              0
# 63674f2475aa7bc3d7bff510   62.500000           0            6              2
#
# ...

# %%
df5=df4.drop(columns=['easyCorrect','easyIncorrect','easyUnanswered','moderateCorrect','moderateIncorrect','moderateUnanswered','toughCorrect','toughIncorrect','toughUnanswered','notVisited','totalAttempted','totalCorrect'],axis=1)
df5.head()
# Out:
#                           totalMarkScored    accuracy  perfectAttempts  \
# id1
# 62a615351ed36c04de22cae7             54.0   71.428571               10
# 62af04539011c8495db99872             77.0   86.956522               16
# 6342cea5c09d95e0e99f9e8b             65.0   85.000000                8
# 63627c74ebd62fc378ced962             12.0  100.000000                2
# 63674f2475aa7bc3d7bff510             51.0   62.500000               13
#
#                           wastedAttempts  overtimeAttempts  confusedAttempts  \
# id1
# 62a615351ed36c04de22cae7               0                 2                 1
# 62af04539011c8495db99872               1                 2                 2
# 6342cea5c09d95e0e99f9e8b               0                 1                 3
# 63627c74ebd62fc378ced962               0                 0                 0
# 63674f2475aa7bc3d7bff510               0                 1                 0
#
# ...

# %%
df5['accuracy']=df5['accuracy'].fillna(0)
df5.head()
# Out:
#                           totalMarkScored    accuracy  perfectAttempts  \
# id1
# 62a615351ed36c04de22cae7             54.0   71.428571               10
# 62af04539011c8495db99872             77.0   86.956522               16
# 6342cea5c09d95e0e99f9e8b             65.0   85.000000                8
# 63627c74ebd62fc378ced962             12.0  100.000000                2
# 63674f2475aa7bc3d7bff510             51.0   62.500000               13
#
#                           wastedAttempts  overtimeAttempts  confusedAttempts  \
# id1
# 62a615351ed36c04de22cae7               0                 2                 1
# 62af04539011c8495db99872               1                 2                 2
# 6342cea5c09d95e0e99f9e8b               0                 1                 3
# 63627c74ebd62fc378ced962               0                 0                 0
# 63674f2475aa7bc3d7bff510               0                 1                 0
#
# ...

# %%
df6=df5.drop(columns=['perfectAttempts','wastedAttempts','overtimeAttempts','confusedAttempts','totalMarkScored'],axis=1)
df6.head(30)
# Out:
#                             accuracy  easyCorrect1  easyIncorrect1  \
# id1
# 62a615351ed36c04de22cae7   71.428571     69.230769       23.076923
# 62af04539011c8495db99872   86.956522     90.909091        9.090909
# 6342cea5c09d95e0e99f9e8b   85.000000     83.333333        8.333333
# 63627c74ebd62fc378ced962  100.000000      0.000000        0.000000
# 63674f2475aa7bc3d7bff510   62.500000     66.666667       22.222222
# 63675af4d047a5c3ff1438c7   70.000000     63.636364       18.181818
# 63676c8e2415b6c4334e482b   76.190476     36.363636       36.363636
# 63830e20430ed352525794a9   95.833333     90.909091        0.000000
# 6383289569f7d55259098f46   95.833333    100.000000        0.000000
# 638a1699430ed352525beece   68.750000     14.285714        5.714286
# 638c49ac483bc85183161a8e   69.565217     60.000000       30.000000
# 638c5861df788451e524fa92   66.666667     60.000000        0.000000
# 638d85fa7f45f851f85780c7  100.000000     82.352941        0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df6_1=sc.fit_transform(df6)
df6_2=pd.DataFrame(df6_1)

# %%
pd.DataFrame(df6_1).describe()
# Out:
#                  0             1             2             3             4   \
# count  1.636300e+04  1.634600e+04  1.634600e+04  1.634600e+04  1.635400e+04
# mean  -4.342374e-16  1.043254e-16 -5.216269e-18 -1.147579e-16 -2.085487e-16
# std    1.000031e+00  1.000031e+00  1.000031e+00  1.000031e+00  1.000031e+00
# min   -4.384710e+00 -2.506882e+00 -1.091476e+00 -1.137121e+00 -2.332516e+00
# 25%   -2.962376e-01 -5.081856e-01 -6.465226e-01 -6.584347e-01 -5.799735e-01
# 50%    1.943791e-01  1.580466e-01 -1.768493e-01 -2.329361e-01  6.412341e-02
# 75%    5.925607e-01  6.910323e-01  4.519567e-01  3.160331e-01  6.414957e-01
# max    1.339151e+00  1.757004e+00  7.140166e+00  2.931710e+00  2.340931e+00
#
#                  5             6             7             8             9   \
# count  1.635400e+04  1.635400e+04  1.627900e+04  1.627900e+04  1.627900e+04
# mean  -4.518555e-17 -1.668389e-16  2.531573e-17 -4.539372e-17  2.723623e-16
# ...

# %%
df6_2.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.296238  0.445039  0.808134 -0.824134 -0.463137  1.453812 -0.263063
# 1  0.592561  1.369378 -0.343145 -1.137121  1.406242 -0.341720 -1.100350
# 2  0.480572  1.046356 -0.405506 -0.798051  0.004207 -1.239486  0.574224
# 3  1.339151 -2.506882 -1.091476  2.931710 -1.482798 -1.239486  1.906272
# 4 -0.807297  0.335708  0.737778 -0.685028 -0.515064  2.251827 -0.588674
#
#          7         8         9         10        11        12
# 0  2.555698 -0.930133 -1.789374 -0.442746  0.876340  0.499077
# 1  0.431646  0.826312 -0.835998 -0.442746  1.206146  1.453586
# 2 -0.984389  1.411794  0.117378 -0.442746  0.161760  0.339992
# 3 -1.161394 -0.930133  1.547443  2.770950 -2.222869 -1.943344
# 4  1.139663 -0.930133 -0.518206 -0.442746  0.711437  0.021822

# %%
from joblib import Parallel, delayed 
import joblib 
  
  
# Save the model as a pickle in a file 
#joblib.dump(m, 'filename.pkl') 
  
# Load the model from the file 
m = joblib.load('filename.pkl') 
  
# Use the loaded model to make predictions 
#knn_from_joblib.predict(X_test)

# %%
df6_2=df6_2.fillna(0)

# %%
df6_1=df6_2.to_numpy()

# %%
import numpy as np
np.any(np.isnan(df6_1))
# Out:
# False

# %%
np.argwhere(np.isnan(df6_1))
# Out:
# array([[   26,     7],
#        [   26,     8],
#        [   26,     9],
#        [   29,     7],
#        [   29,     8],
#        [   29,     9],
#        [   72,     7],
#        [   72,     8],
#        [   72,     9],
#        [  131,     1],
#        [  131,     2],
#        [  131,     3],
#        [  163,     7],
#        [  163,     8],
#        [  163,     9],
#        [  178,     7],
#        [  178,     8],
#        [  178,     9],
#        [  379,     7],
#        [  379,     8],
#        [  379,     9],
#        [  420,     7],
#        [  420,     8],
#        [  420,     9],
#        [  490,     7],
#        [  490,     8],
#        [  490,     9],
#        [  561,     7],
#        [  561,     8],
#        [  561,     9],
#        [  578,     7],
#        [  578,     8],
#        [  578,     9],
#        [  633,     7],
#        [  633,     8],
#        [  633,     9],
#        [  667,     7],
#        [  667,     8],
#        [  667,     9],
#        [  685,     1],
# ...

# %%
pred=m.predict(df6_1)

# %%
pred
# Out:
# array([3, 3, 2, ..., 3, 0, 0], dtype=int32)

# %%
df6['pred']=pred
df6['pred'].value_counts()
# Out:
# pred
# 2    6828
# 4    2868
# 3    2634
# 1    2313
# 0    1720
# Name: count, dtype: int64

# %%
df6[df6['pred']==0].head()
# Out:
#                             accuracy  easyCorrect1  easyIncorrect1  \
# id1
# 63627c74ebd62fc378ced962  100.000000      0.000000        0.000000
# 638a1699430ed352525beece   68.750000     14.285714        5.714286
# 63922a20b36b5d51d3abd2ae   56.666667     11.764706       20.588235
# 63a72670869dc38b36e629fd   25.000000      3.225806        3.225806
# 63b0543d1f48cc8a94041d48   51.851852     20.000000       17.142857
#
#                           easyUnanswered1  moderateCorrect1  \
# id1
# 63627c74ebd62fc378ced962       100.000000         18.181818
# 638a1699430ed352525beece        80.000000          8.823529
# 63922a20b36b5d51d3abd2ae        67.647059         32.432432
# 63a72670869dc38b36e629fd        93.548387          0.000000
# 63b0543d1f48cc8a94041d48        62.857143         13.888889
#
#                           moderateIncorrect1  moderateUnanswered1  \
# id1
# 63627c74ebd62fc378ced962            0.000000            81.818182
# ...

# %%
df22.head()
# Out:
#                         _id                    userId  \
# 0  62a615351ed36c04de22cae7  62a5b3562f2c8edf02cd8f28
# 1  62af04539011c8495db99872  62a5b3562f2c8edf02cd8f28
# 2  6342cea5c09d95e0e99f9e8b  6342b29ce77795e149e62052
# 3  63627c74ebd62fc378ced962  63542c772ef4ea103afdf799
# 4  63674f2475aa7bc3d7bff510  6342b29ce77795e149e62052
#
#                      testId  notVisited  \
# 0  629c1fffa267606d24fb7411           0
# 1  629c5b8f8f253e5778bd86a8           0
# 2  62d048869f6e5150d0b4fc0f           0
# 3  62d04863c6a09e2c86a69d09          14
# 4  62d04878cb20fa1bfa8e349a           0
#
#                                             subjects  \
# 0  [{'painfulQuestions': [{'$oid': '62a41b00acc3c...
# 1  [{'painfulQuestions': [{'$oid': '62ab299c44ccb...
# 2  [{'painfulQuestions': [{'$oid': '617aaa1eef3fe...
# 3  [{'painfulQuestions': [], 'missedConcepts': []...
# 4  [{'painfulQuestions': [{'$oid': '617aa9eaef3fe...
#
#                                            questions  \
# ...

# %%
df6=df6.merge(df22[['userId','testId','_id']],how='left',left_index=True,right_on='_id')
df6.head()
# Out:
#      accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# 0   71.428571     69.230769       23.076923         7.692308
# 1   86.956522     90.909091        9.090909         0.000000
# 2   85.000000     83.333333        8.333333         8.333333
# 3  100.000000      0.000000        0.000000       100.000000
# 4   62.500000     66.666667       22.222222        11.111111
#
#    moderateCorrect1  moderateIncorrect1  moderateUnanswered1  toughCorrect1  \
# 0         40.000000           30.000000            30.000000     100.000000
# 1         80.000000           10.000000            10.000000      50.000000
# 2         50.000000            0.000000            50.000000      16.666667
# 3         18.181818            0.000000            81.818182      12.500000
# 4         38.888889           38.888889            22.222222      66.666667
#
#    toughIncorrect1  toughUnanswered1  notVisited1  totalAttempted1  \
# 0         0.000000          0.000000     0.000000        84.000000
# ...

# %%
df6.groupby(['userId']).first()
# Out:
#                             accuracy  easyCorrect1  easyIncorrect1  \
# userId
# 62a5b3562f2c8edf02cd8f28   71.428571     69.230769       23.076923
# 62fa83240a17af8738a2c04a   25.000000      3.225806        3.225806
# 63301744aae5e0e0ca524661   64.000000     28.571429       21.428571
# 6342b29ce77795e149e62052   85.000000     83.333333        8.333333
# 63542c772ef4ea103afdf799  100.000000      0.000000        0.000000
# ...                              ...           ...             ...
# 65f5a72ae513591ab3116b3b    0.000000      0.000000        0.000000
# 65f82a38c62c0f1aa2b68842   82.812500     77.419355        3.225806
# 65fbc0fbf534461a83b2b654   79.687500     70.967742       16.129032
# 65fbf2970160d51b03229a90   83.333333     70.000000        6.666667
# 65fd780dc428001b33cb6c62   70.588235     51.612903       16.129032
#
#                           easyUnanswered1  moderateCorrect1  \
# userId
# 62a5b3562f2c8edf02cd8f28         7.692308         40.000000
# ...

# %%
with open('strapi-admin-panel.basic_analyses_aprilpred.json') as outf:
    df=json.load(outf)
df7=pd.DataFrame.from_dict(df)
df7.head()
# Out:
#                                     _id                                testId  \
# 0  {'$oid': '6604b8a7d0e3211afb33113b'}  {'$oid': '65b21c7cacca0541e9d3907c'}
# 1  {'$oid': '65ffff177ac3331a9bac927b'}  {'$oid': '65b21c7cacca0541e9d39092'}
# 2  {'$oid': '65fc6e02c56f3d1a8a615830'}  {'$oid': '65b21c7cacca0541e9d3908c'}
# 3  {'$oid': '65f976cec62c0f1aa2c60c29'}  {'$oid': '65b21c7cacca0541e9d3908a'}
# 4  {'$oid': '65f5bbc5c56f3d1a8a0dcc55'}  {'$oid': '65b220a9acca0541e9d390ba'}
#
#                                  userId  isBonusAttempted  \
# 0  {'$oid': '62a5b3562f2c8edf02cd8f28'}             False
# 1  {'$oid': '62a5b3562f2c8edf02cd8f28'}             False
# 2  {'$oid': '62a5b3562f2c8edf02cd8f28'}             False
# 3  {'$oid': '62a5b3562f2c8edf02cd8f28'}             False
# 4  {'$oid': '62a5b3562f2c8edf02cd8f28'}             False
#
#                                             sections  \
# 0  [{'_id': {'$oid': '6604b8a7d0e3211afb33113c'},...
# ...

# %%
df7['_id1']=df7['_id'].apply(lambda x:x.get('$oid'))
df7['testid1']=df7['testId'].apply(lambda x:x.get('$oid'))
df7['userid1']=df7['userId'].apply(lambda x:x.get('$oid'))
df7.head()
# Out:
#                                     _id                                testId  \
# 0  {'$oid': '6604b8a7d0e3211afb33113b'}  {'$oid': '65b21c7cacca0541e9d3907c'}
# 1  {'$oid': '65ffff177ac3331a9bac927b'}  {'$oid': '65b21c7cacca0541e9d39092'}
# 2  {'$oid': '65fc6e02c56f3d1a8a615830'}  {'$oid': '65b21c7cacca0541e9d3908c'}
# 3  {'$oid': '65f976cec62c0f1aa2c60c29'}  {'$oid': '65b21c7cacca0541e9d3908a'}
# 4  {'$oid': '65f5bbc5c56f3d1a8a0dcc55'}  {'$oid': '65b220a9acca0541e9d390ba'}
#
#                                  userId  isBonusAttempted  \
# 0  {'$oid': '62a5b3562f2c8edf02cd8f28'}             False
# 1  {'$oid': '62a5b3562f2c8edf02cd8f28'}             False
# 2  {'$oid': '62a5b3562f2c8edf02cd8f28'}             False
# 3  {'$oid': '62a5b3562f2c8edf02cd8f28'}             False
# 4  {'$oid': '62a5b3562f2c8edf02cd8f28'}             False
#
#                                             sections  \
# 0  [{'_id': {'$oid': '6604b8a7d0e3211afb33113c'},...
# ...

# %%
df7.drop(['_id','userId','testId'],axis=1,inplace=True)
df7.head()
# Out:
#    isBonusAttempted                                           sections  \
# 0             False  [{'_id': {'$oid': '6604b8a7d0e3211afb33113c'},...
# 1             False  [{'_id': {'$oid': '65ffff177ac3331a9bac927c'},...
# 2             False  [{'_id': {'$oid': '65fc6e02c56f3d1a8a615831'},...
# 3             False  [{'_id': {'$oid': '65f976cec62c0f1aa2c60c2a'},...
# 4             False  [{'_id': {'$oid': '65f5bbc5c56f3d1a8a0dcc56'},...
#
#                                             subjects  totalTimeTaken  \
# 0  [{'_id': {'$oid': '6604b8a7d0e3211afb3311c9'},...           10370
# 1  [{'_id': {'$oid': '65ffff177ac3331a9bac92ff'},...           10244
# 2  [{'_id': {'$oid': '65fc6e02c56f3d1a8a6158b9'},...           10265
# 3  [{'_id': {'$oid': '65f976cec62c0f1aa2c60cad'},...            9393
# 4  [{'_id': {'$oid': '65f5bbc5c56f3d1a8a0dccc2'},...            4228
#
#    totalMarkScored  totalAttempted  totalCorrect   accuracy  \
# ...

# %%
df8=pd.DataFrame([tuple(list(d.values()))+(tup._11,tup.testid1,tup.userid1) for tup in df7.itertuples() for d in tup.sections])
df8.columns=list(df7['sections'][0][0].keys())+['id1','testid','userdid']
df8.head()
# Out:
#                                     _id                             sectionId  \
# 0  {'$oid': '6604b8a7d0e3211afb33113c'}  {'$oid': '65d8d666ea0e0673ca350518'}
# 1  {'$oid': '6604b8a7d0e3211afb331161'}  {'$oid': '65d8d666ea0e0673ca350595'}
# 2  {'$oid': '6604b8a7d0e3211afb33116c'}  {'$oid': '65d8d667ea0e0673ca35068a'}
# 3  {'$oid': '6604b8a7d0e3211afb331193'}  {'$oid': '65d8d667ea0e0673ca350707'}
# 4  {'$oid': '6604b8a7d0e3211afb33119e'}  {'$oid': '65d8d667ea0e0673ca3507fc'}
#
#                                            questions  \
# 0  [{'_id': {'$oid': '6604b8a7d0e3211afb33113d'},...
# 1  [{'_id': {'$oid': '6604b8a7d0e3211afb331162'},...
# 2  [{'_id': {'$oid': '6604b8a7d0e3211afb33116d'},...
# 3  [{'_id': {'$oid': '6604b8a7d0e3211afb331194'},...
# 4  [{'_id': {'$oid': '6604b8a7d0e3211afb33119f'},...
#
#                                             analysis  \
# 0  {'totalTimeTaken': 3010, 'totalMarkScored': 44...
# 1  {'totalTimeTaken': 1113, 'totalMarkScored': 20...
# ...

# %%
df9=pd.DataFrame([tuple(list(d.values()))+(tup.id1,tup.testid,tup.userdid) for tup in df8.itertuples() for d in tup.questions])
df9.columns=list(df8['questions'][0][0].keys())+['id1','testid','userdid']
df9.head()
# Out:
#                                     _id                            questionId  \
# 0  {'$oid': '6604b8a7d0e3211afb33113d'}  {'$oid': '65d8d666ea0e0673ca3504b1'}
# 1  {'$oid': '6604b8a7d0e3211afb33113f'}  {'$oid': '65d8d666ea0e0673ca3504b6'}
# 2  {'$oid': '6604b8a7d0e3211afb331141'}  {'$oid': '65d8d666ea0e0673ca3504bb'}
# 3  {'$oid': '6604b8a7d0e3211afb331143'}  {'$oid': '65d8d666ea0e0673ca3504c0'}
# 4  {'$oid': '6604b8a7d0e3211afb331145'}  {'$oid': '65d8d666ea0e0673ca3504c5'}
#
#                                        markedOptions  \
# 0  [{'_id': {'$oid': '6604b8a7d0e3211afb33113e'},...
# 1  [{'_id': {'$oid': '6604b8a7d0e3211afb331140'},...
# 2  [{'_id': {'$oid': '6604b8a7d0e3211afb331142'},...
# 3  [{'_id': {'$oid': '6604b8a7d0e3211afb331144'},...
# 4  [{'_id': {'$oid': '6604b8a7d0e3211afb331146'},...
#
#                             inputValue  timeTaken timeLeftWhenAttempted  \
# 0  {'value': None, 'isCorrect': False}      142.0                   178
# ...

# %%
a13=pd.Series([type(x) for x in df9['inputValue']]).unique()
df9['ty1']=[type(x) for x in df9['inputValue']]

# %%
df9_1=df9[df9['ty1']==a13[1]]

# %%
df9_1.head()
# Out:
#                                         _id  \
# 42472  {'$oid': '648dadd876efa92202a6d44d'}
# 42473  {'$oid': '648dadd876efa92202a6d44f'}
# 42474  {'$oid': '648dadd876efa92202a6d451'}
# 42475  {'$oid': '648dadd876efa92202a6d454'}
# 42476  {'$oid': '648dadd876efa92202a6d456'}
#
#                                  questionId  \
# 42472  {'$oid': '6438289bf9c2e9ce9ed3f3c4'}
# 42473  {'$oid': '6438289bf9c2e9ce9ed3f3c9'}
# 42474  {'$oid': '6438289bf9c2e9ce9ed3f3ce'}
# 42475  {'$oid': '6438289bf9c2e9ce9ed3f3ed'}
# 42476  {'$oid': '6438289bf9c2e9ce9ed3f3f2'}
#
#                                            markedOptions inputValue  \
# 42472  [{'_id': {'$oid': '648dadd876efa92202a6d44e'},...          7
# 42473  [{'_id': {'$oid': '648dadd876efa92202a6d450'},...         83
# 42474  [{'_id': {'$oid': '648dadd876efa92202a6d452'},...         30
# 42475  [{'_id': {'$oid': '648dadd876efa92202a6d455'},...         24
# 42476                                                 []          0
#
# ...

# %%
df9.loc[df9['ty1']==a13[1],['inputValue','timeTaken','timeLeftWhenAttempted','status','id1','testid','userdid']]=df9.loc[df9['ty1']==a13[1],['inputValue','timeTaken','timeLeftWhenAttempted','status','id1','testid','userdid']].shift(1,axis=1)
# Out:
# /var/folders/vr/2kzmkbl5167_gtmslwch1dtw0000gn/T/ipykernel_73493/2599898340.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[7 83 30 ... 510 13 132]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df9.loc[df9['ty1']==a13[1],['inputValue','timeTaken','timeLeftWhenAttempted','status','id1','testid','userdid']]=df9.loc[df9['ty1']==a13[1],['inputValue','timeTaken','timeLeftWhenAttempted','status','id1','testid','userdid']].shift(1,axis=1)

# %%
set([type(x) for x in df9['inputValue']])
# Out:
# {dict, str}

# %%
df9['inputValue'].replace(to_replace=[None],value=[{'value':'Hello'}],inplace=True)
# Out:
# /var/folders/vr/2kzmkbl5167_gtmslwch1dtw0000gn/T/ipykernel_73493/1620196301.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df9['inputValue'].replace(to_replace=[None],value=[{'value':'Hello'}],inplace=True)

# %%
df9[df9['ty1']==a13[1]]
# Out:
#                                           _id  \
# 42472    {'$oid': '648dadd876efa92202a6d44d'}
# 42473    {'$oid': '648dadd876efa92202a6d44f'}
# 42474    {'$oid': '648dadd876efa92202a6d451'}
# 42475    {'$oid': '648dadd876efa92202a6d454'}
# 42476    {'$oid': '648dadd876efa92202a6d456'}
# ...                                       ...
# 1124902  {'$oid': '6643cdeb84d4ccd474b23d58'}
# 1124903  {'$oid': '6643cdeb84d4ccd474b23d59'}
# 1124904  {'$oid': '6643cdeb84d4ccd474b23d5c'}
# 1124905  {'$oid': '6643cdeb84d4ccd474b23d5e'}
# 1124906  {'$oid': '6643cdeb84d4ccd474b23d5f'}
#
#                                    questionId  \
# 42472    {'$oid': '6438289bf9c2e9ce9ed3f3c4'}
# 42473    {'$oid': '6438289bf9c2e9ce9ed3f3c9'}
# 42474    {'$oid': '6438289bf9c2e9ce9ed3f3ce'}
# 42475    {'$oid': '6438289bf9c2e9ce9ed3f3ed'}
# 42476    {'$oid': '6438289bf9c2e9ce9ed3f3f2'}
# ...                                       ...
# 1124902  {'$oid': '65ce2e8e427837fff8cb9b23'}
# ...

# %%
df9_1

# %%
df9_1['testid'].nunique()
# Out:
# 39

# %%
a12=[]
for i in df9.itertuples():
    if len(i.markedOptions)==0:
        if i.inputValue.get('value')=='Hello' and (i.status=='notAnswered' or i.status=='markedReview'):
            a12.append(-1)
        else:
            if i.inputValue.get('isCorrect')==False:
                a12.append(0)
            else:
                a12.append(1)
        
    else:
        #df6.loc[i.Index,'status']='answered'
        if i.markedOptions[0].get('isCorrect')==True:
            a12.append(1)
        else:
            a12.append(0)
df9['hans']=a12

# %%
with open('strapi-admin-panel.questions_main.json') as outf:
    df=json.load(outf)
pd.set_option('display.max_columns',None)
df10=pd.DataFrame.from_dict(df)
df10.head()
# Out:
#                                     _id classes  \
# 0  {'$oid': '65742f2699fd55951d1a3b4d'}      []
# 1  {'$oid': '65742f2699fd55951d1a3b52'}      []
# 2  {'$oid': '65742f2699fd55951d1a3b57'}      []
# 3  {'$oid': '65742f2699fd55951d1a3b5c'}      []
# 4  {'$oid': '65742f2699fd55951d1a3b61'}      []
#
#                                     exams  \
# 0  [{'$oid': '605dfcb2f226ac25a8bd5fef'}]
# 1  [{'$oid': '605dfcb2f226ac25a8bd5fef'}]
# 2  [{'$oid': '605dfcb2f226ac25a8bd5fef'}]
# 3  [{'$oid': '605dfcb2f226ac25a8bd5fef'}]
# 4  [{'$oid': '605dfcb2f226ac25a8bd5fef'}]
#
#                                  subjects  \
# 0  [{'$oid': '607018ee404ae53194e73d90'}]
# 1  [{'$oid': '607018ee404ae53194e73d90'}]
# 2  [{'$oid': '607018ee404ae53194e73d90'}]
# 3  [{'$oid': '607018ee404ae53194e73d90'}]
# 4  [{'$oid': '607018ee404ae53194e73d90'}]
#
#                                  chapters  \
# 0  [{'$oid': '60c9e849ea076dc381c0df7b'}]
# 1  [{'$oid': '60d2d1d2185d7a32fa3205a7'}]
# ...

# %%
df10['subjects']=df10['subjects'].apply(lambda x:x[0].get('$oid'))
df10['_id']=df10['_id'].apply(lambda x:x.get('$oid'))
df10.head()
# Out:
#                         _id classes                                   exams  \
# 0  65742f2699fd55951d1a3b4d      []  [{'$oid': '605dfcb2f226ac25a8bd5fef'}]
# 1  65742f2699fd55951d1a3b52      []  [{'$oid': '605dfcb2f226ac25a8bd5fef'}]
# 2  65742f2699fd55951d1a3b57      []  [{'$oid': '605dfcb2f226ac25a8bd5fef'}]
# 3  65742f2699fd55951d1a3b5c      []  [{'$oid': '605dfcb2f226ac25a8bd5fef'}]
# 4  65742f2699fd55951d1a3b61      []  [{'$oid': '605dfcb2f226ac25a8bd5fef'}]
#
#                    subjects                                chapters  \
# 0  607018ee404ae53194e73d90  [{'$oid': '60c9e849ea076dc381c0df7b'}]
# 1  607018ee404ae53194e73d90  [{'$oid': '60d2d1d2185d7a32fa3205a7'}]
# 2  607018ee404ae53194e73d90  [{'$oid': '60c9e849ea076dc381c0dfa9'}]
# 3  607018ee404ae53194e73d90  [{'$oid': '60da9b5062f042332c538358'}]
# 4  607018ee404ae53194e73d90  [{'$oid': '60e2fadb66f9ce3f243b4798'}]
#
#                                    topics  \
# 0  [{'$oid': '6117b651478ae845c43c6921'}]
# ...

# %%
df9['questionId']=df9['questionId'].apply(lambda x:x.get('$oid'))

# %%
df11=df9.merge(df10[['_id','subjects','type','level','approximateTimeRequired']],how='left',left_on='questionId',right_on='_id')
df11=df11.query("hans!=-1 or (status!='answered' and status!='answeredReview')")
df12=df11.query("hans==0 and (status=='notAnswered' or status=='markedReview')")
df12=df12.reset_index()
df12.head()
# Out:
#    index                                 _id_x                questionId  \
# 0      6  {'$oid': '6604b8a7d0e3211afb331149'}  65d8d666ea0e0673ca3504cf
# 1      8  {'$oid': '6604b8a7d0e3211afb33114c'}  65d8d666ea0e0673ca3504d9
# 2      9  {'$oid': '6604b8a7d0e3211afb33114d'}  65d8d666ea0e0673ca3504de
# 3     16  {'$oid': '6604b8a7d0e3211afb33115a'}  65d8d666ea0e0673ca350501
# 4     21  {'$oid': '6604b8a7d0e3211afb331163'}  65d8d666ea0e0673ca350565
#
#   markedOptions                           inputValue timeTaken  \
# 0            []   {'value': '0', 'isCorrect': False}     107.0
# 1            []   {'value': '0', 'isCorrect': False}      83.0
# 2            []   {'value': '0', 'isCorrect': False}      67.0
# 3            []  {'value': None, 'isCorrect': False}      12.0
# 4            []    {'value': '', 'isCorrect': False}       7.0
#
#   timeLeftWhenAttempted       status                       id1  \
# 0                    10  notAnswered  6604b8a7d0e3211afb33113b
# ...

# %%
df12['status']='answered'

# %%
df12.rename(columns={'index':'A'},inplace=True)

# %%
df11.loc[df11.index.isin(df12.A),['status']]=df12['status']
df11['ty']=[type(x) for x in df11['timeTaken']]
df11['ty'].value_counts()
# Out:
# ty
# <class 'float'>    1124362
# <class 'int'>         3456
# Name: count, dtype: int64

# %%
#a13=df11['ty'].unique()
#ind=df11[df11['ty']==a13[1]].index
#df11.drop(ind,inplace=True)
df13=df11.groupby(['testid','userdid','subjects','type','status','hans'])[['timeTaken','approximateTimeRequired']].sum()
df13=df13.reset_index()

# %%
df13['nstat']=df13['status'].map({'notAnswered':0,'markedReview':0,'answered':1,'answeredReview':1,'notVisited':-1})
df13.head()
# Out:
#                      testid                   userdid  \
# 0  641588b7ba53754de28c8935  63301744aae5e0e0ca524661
# 1  641588b7ba53754de28c8935  63301744aae5e0e0ca524661
# 2  641588b7ba53754de28c8935  63301744aae5e0e0ca524661
# 3  641588b7ba53754de28c8935  63301744aae5e0e0ca524661
# 4  641588b7ba53754de28c8935  63301744aae5e0e0ca524661
#
#                    subjects           type      status  hans timeTaken  \
# 0  607018ee404ae53194e73d90      numerical    answered     0     988.0
# 1  607018ee404ae53194e73d90      numerical    answered     1     329.0
# 2  607018ee404ae53194e73d90      numerical  notVisited     0       0.0
# 3  607018ee404ae53194e73d90  singleCorrect    answered     0     119.0
# 4  607018ee404ae53194e73d90  singleCorrect    answered     1    1659.0
#
#    approximateTimeRequired  nstat
# 0                    960.0      1
# 1                    330.0      1
# 2                    150.0     -1
# 3                    120.0      1
# 4                   2010.0      1

# %%
df111=df13.groupby(['userdid','testid'])['timeTaken'].sum()

# %%
df111=df111.reset_index()

# %%
df111.head()
# Out:
#                     userdid                    testid timeTaken
# 0  63301744aae5e0e0ca524661  641588b7ba53754de28c8935   10975.0
# 1  63301744aae5e0e0ca524661  641588b7ba53754de28c8937   11570.0
# 2  63301744aae5e0e0ca524661  641588b7ba53754de28c8939   10720.0
# 3  63301744aae5e0e0ca524661  641588b7ba53754de28c893b   10746.0
# 4  63301744aae5e0e0ca524661  641588b7ba53754de28c893d   10660.0

# %%
df6.head()
# Out:
#      accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# 0   71.428571     69.230769       23.076923         7.692308
# 1   86.956522     90.909091        9.090909         0.000000
# 2   85.000000     83.333333        8.333333         8.333333
# 3  100.000000      0.000000        0.000000       100.000000
# 4   62.500000     66.666667       22.222222        11.111111
#
#    moderateCorrect1  moderateIncorrect1  moderateUnanswered1  toughCorrect1  \
# 0         40.000000           30.000000            30.000000     100.000000
# 1         80.000000           10.000000            10.000000      50.000000
# 2         50.000000            0.000000            50.000000      16.666667
# 3         18.181818            0.000000            81.818182      12.500000
# 4         38.888889           38.888889            22.222222      66.666667
#
#    toughIncorrect1  toughUnanswered1  notVisited1  totalAttempted1  \
# 0         0.000000          0.000000     0.000000        84.000000
# ...

# %%
df6['userId'].nunique()
# Out:
# 357

# %%
df6_1=df6.merge(df111,how='left',left_on=['userId','testId'],right_on=['userdid','testid'])
df6_1.head()
# Out:
#      accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# 0   71.428571     69.230769       23.076923         7.692308
# 1   86.956522     90.909091        9.090909         0.000000
# 2   85.000000     83.333333        8.333333         8.333333
# 3  100.000000      0.000000        0.000000       100.000000
# 4   62.500000     66.666667       22.222222        11.111111
#
#    moderateCorrect1  moderateIncorrect1  moderateUnanswered1  toughCorrect1  \
# 0         40.000000           30.000000            30.000000     100.000000
# 1         80.000000           10.000000            10.000000      50.000000
# 2         50.000000            0.000000            50.000000      16.666667
# 3         18.181818            0.000000            81.818182      12.500000
# 4         38.888889           38.888889            22.222222      66.666667
#
#    toughIncorrect1  toughUnanswered1  notVisited1  totalAttempted1  \
# 0         0.000000          0.000000     0.000000        84.000000
# ...

# %%
df6_2=df6_1.query('timeTaken.notna() and timeTaken>=7200')

# %%
df6_2[df6_2['pred']==4].describe()
# Out:
#          accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# count  292.000000    292.000000      292.000000       292.000000
# mean    74.677262     50.868981       15.642432        33.488587
# std      7.423485      8.063030        7.332961         8.434068
# min     51.063830     29.411765        0.000000        15.625000
# 25%     70.370370     45.161290        9.677419        27.586207
# 50%     74.509804     50.000000       15.625000        32.258065
# 75%     79.591837     56.250000       20.000000        38.754480
# max     97.297297     70.967742       35.483871        58.620690
#
#        moderateCorrect1  moderateIncorrect1  moderateUnanswered1  \
# count        292.000000          292.000000           292.000000
# mean          41.081192           14.046240            44.872568
# std            7.146747            6.522223             8.050041
# min           18.918919            0.000000            24.242424
# ...

# %%
df6_2[df6_2['pred']==3].describe()
# Out:
#          accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# count  106.000000    106.000000      106.000000       106.000000
# mean    88.389612     80.067432        7.635460        12.297108
# std      4.445723      6.969327        5.034619         5.079444
# min     76.000000     62.068966        0.000000         0.000000
# 25%     86.111111     75.000000        3.333333         9.375000
# 50%     88.000000     80.600358        6.666667        11.942959
# 75%     91.692759     84.375000       10.000000        16.129032
# max    100.000000     96.969697       21.875000        25.000000
#
#        moderateCorrect1  moderateIncorrect1  moderateUnanswered1  \
# count        106.000000          106.000000           106.000000
# mean          69.061961           10.393889            20.544150
# std            6.497727            5.464327             4.833560
# min           51.351351            0.000000             7.894737
# ...

# %%
df6_2[df6_2['pred']==2].describe()
# Out:
#           accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# count  1589.000000   1589.000000     1589.000000      1589.000000
# mean     82.945926     67.401461       11.732199        20.866340
# std       5.650740      9.139192        6.286688         7.827395
# min      69.642857     37.500000        0.000000         0.000000
# 25%      78.688525     61.290323        6.451613        15.625000
# 50%      82.812500     67.647059       11.111111        20.588235
# 75%      87.096774     73.333333       15.625000        25.806452
# max      98.076923     96.774194       38.709677        50.000000
#
#        moderateCorrect1  moderateIncorrect1  moderateUnanswered1  \
# count       1589.000000         1589.000000          1589.000000
# mean          55.884255           11.980850            32.134896
# std            8.742240            5.738862             8.519717
# min           28.947368            0.000000            11.111111
# ...

# %%
df6_2[df6_2['pred']==1].describe()
# Out:
#          accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# count  166.000000    166.000000      166.000000       166.000000
# mean    67.038201     56.499845       23.665162        19.834992
# std      4.729650     10.072954        7.396269         7.817597
# min     47.272727     31.250000        6.451613         3.333333
# 25%     64.406780     50.000000       18.750000        14.705882
# 50%     68.126984     58.064516       23.529412        19.052419
# 75%     70.564127     64.516129       28.125000        25.000000
# max     74.666667     77.419355       46.875000        55.882353
#
#        moderateCorrect1  moderateIncorrect1  moderateUnanswered1  \
# count        166.000000          166.000000           166.000000
# mean          48.942193           22.647061            28.410746
# std            8.940966            6.379284             8.338015
# min           27.027027            9.375000             8.333333
# ...

# %%
df1_1_1.head()
# Out:
#       Your registered email id  Your registered mobile number  Percentile
# 0  priyanshujha.pj06@gmail.com                     8668606304   99.197164
# 1      vidhitalwar01@gmail.com                     8273002370   99.003291
# 2      upwordhill987@gmail.com                     9625497741   99.443676
# 3          rs.raag17@gmail.com                     9560806945   99.728357
# 4    maheshbarik2006@gmail.com                     8093378029   99.295775

# %%
df1_1.head()
# Out:
#                         _id  \
# 0  659e7914f31a489e0e120ecb
# 1  65a9f052c3d3af1fe919a4c5
# 2  655cbdacb986585c9175e8e4
# 3  6593d648ba0c875fa67a4a3f
# 4  6568b8dc0be0949faa6e1e19
#
#                                             settings  \
# 0  {'emails': True, 'importantEmails': True, 'imp...
# 1  {'emails': True, 'importantEmails': True, 'imp...
# 2  {'emails': True, 'importantEmails': True, 'imp...
# 3  {'emails': True, 'importantEmails': True, 'imp...
# 4  {'emails': True, 'importantEmails': True, 'imp...
#
#                                          targetExams FCM_TOKEN  \
# 0  [{'$oid': '605dfcb2f226ac25a8bd5fef'}, {'$oid'...        []
# 1  [{'$oid': '605dfcb2f226ac25a8bd5fef'}, {'$oid'...        []
# 2  [{'$oid': '605dfcb2f226ac25a8bd5ff0'}, {'$oid'...        []
# 3             [{'$oid': '605dfcb2f226ac25a8bd5ff0'}]        []
# 4  [{'$oid': '605dfcb2f226ac25a8bd5ff0'}, {'$oid'...        []
#
#   notificationTopics notifications  isWhatsAppNumber isAllPacksAllowed  \
# ...

# %%
df6_1.head()
# Out:
#      accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# 0   71.428571     69.230769       23.076923         7.692308
# 1   86.956522     90.909091        9.090909         0.000000
# 2   85.000000     83.333333        8.333333         8.333333
# 3  100.000000      0.000000        0.000000       100.000000
# 4   62.500000     66.666667       22.222222        11.111111
#
#    moderateCorrect1  moderateIncorrect1  moderateUnanswered1  toughCorrect1  \
# 0         40.000000           30.000000            30.000000     100.000000
# 1         80.000000           10.000000            10.000000      50.000000
# 2         50.000000            0.000000            50.000000      16.666667
# 3         18.181818            0.000000            81.818182      12.500000
# 4         38.888889           38.888889            22.222222      66.666667
#
#    toughIncorrect1  toughUnanswered1  notVisited1  totalAttempted1  \
# 0         0.000000          0.000000     0.000000        84.000000
# ...

# %%
df6_1['userdid'].nunique()
# Out:
# 232

# %%
df6_1=df6_1.merge(df1_1[['_id','email']],how='left',left_on='userId',right_on='_id')

# %%
df6_1.head()
# Out:
#      accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# 0   71.428571     69.230769       23.076923         7.692308
# 1   86.956522     90.909091        9.090909         0.000000
# 2   85.000000     83.333333        8.333333         8.333333
# 3  100.000000      0.000000        0.000000       100.000000
# 4   62.500000     66.666667       22.222222        11.111111
#
#    moderateCorrect1  moderateIncorrect1  moderateUnanswered1  toughCorrect1  \
# 0         40.000000           30.000000            30.000000     100.000000
# 1         80.000000           10.000000            10.000000      50.000000
# 2         50.000000            0.000000            50.000000      16.666667
# 3         18.181818            0.000000            81.818182      12.500000
# 4         38.888889           38.888889            22.222222      66.666667
#
#    toughIncorrect1  toughUnanswered1  notVisited1  totalAttempted1  \
# 0         0.000000          0.000000     0.000000        84.000000
# ...

# %%
df6_1=df6_1.merge(df1_1_1,how='left',left_on='email',right_on='Your registered email id')

# %%
df6_1.head()
# Out:
#      accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# 0   71.428571     69.230769       23.076923         7.692308
# 1   86.956522     90.909091        9.090909         0.000000
# 2   85.000000     83.333333        8.333333         8.333333
# 3  100.000000      0.000000        0.000000       100.000000
# 4   62.500000     66.666667       22.222222        11.111111
#
#    moderateCorrect1  moderateIncorrect1  moderateUnanswered1  toughCorrect1  \
# 0         40.000000           30.000000            30.000000     100.000000
# 1         80.000000           10.000000            10.000000      50.000000
# 2         50.000000            0.000000            50.000000      16.666667
# 3         18.181818            0.000000            81.818182      12.500000
# 4         38.888889           38.888889            22.222222      66.666667
#
#    toughIncorrect1  toughUnanswered1  notVisited1  totalAttempted1  \
# 0         0.000000          0.000000     0.000000        84.000000
# ...

# %%
df6_1.groupby('pred')['Percentile'].mean()
# Out:
# pred
# 0    99.352927
# 1    99.361514
# 2    99.380721
# 3    99.413641
# 4    99.299586
# Name: Percentile, dtype: float64

# %%
df6_2=df6_1.query('timeTaken.notna() and timeTaken>=7200')

# %%
df6_2.groupby('pred')['Percentile'].mean()
# Out:
# pred
# 1    99.314320
# 2    99.361892
# 3    99.422466
# 4    99.217055
# Name: Percentile, dtype: float64

# %%
df6_2.head()
# Out:
#        accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# 2622  91.666667     70.967742        3.225806        25.806452
# 2625  90.322581     74.193548        6.451613        19.354839
# 2631  69.354839     61.290323       19.354839        19.354839
# 2639  81.967213     70.967742        9.677419        19.354839
# 2647  74.074074     64.516129       16.129032        19.354839
#
#       moderateCorrect1  moderateIncorrect1  moderateUnanswered1  \
# 2622         38.888889            5.555556            55.555556
# 2625         58.333333            5.555556            36.111111
# 2631         41.666667           25.000000            33.333333
# 2639         55.555556            8.333333            36.111111
# 2647         41.666667           16.666667            41.666667
#
#       toughCorrect1  toughIncorrect1  toughUnanswered1  notVisited1  \
# 2622      34.782609         4.347826         60.869565     8.163265
# ...

# %%
df6_3=df6_2[['userId','pred']]

# %%
df6_4=df6_3.groupby('userId')['pred'].apply(lambda x:x.value_counts().index[0]).reset_index()

# %%
df6_4.head()
# Out:
#                      userId  pred
# 0  63301744aae5e0e0ca524661     2
# 1  6342b29ce77795e149e62052     2
# 2  638c92c92a218b511912ab89     4
# 3  63a09470a5cd778b9380ba27     2
# 4  63bd94531b5ec58b581b4f51     2

# %%
df6_4['pred'].value_counts()
# Out:
# pred
# 2    178
# 4     22
# 1      7
# 3      4
# Name: count, dtype: int64

# %%
df6_1_1=df6_1.groupby('userId')['pred'].apply(lambda x:x.value_counts().index[0]).reset_index()
df6_1_1['pred'].value_counts()
# Out:
# pred
# 2    223
# 4     49
# 3     32
# 1     28
# 0     25
# Name: count, dtype: int64

# %%
df6_1_1.head()
# Out:
#                      userId  pred
# 0  62a5b3562f2c8edf02cd8f28     2
# 1  62fa83240a17af8738a2c04a     2
# 2  63301744aae5e0e0ca524661     4
# 3  6342b29ce77795e149e62052     2
# 4  63542c772ef4ea103afdf799     0

# %%
df6_1_1[df6_1_1['pred']==0]
# Out:
#                        userId  pred
# 4    63542c772ef4ea103afdf799     0
# 16   63e4ead10dd35d45089260b0     0
# 23   64273ab23bb1f2c5cdf1954e     0
# 29   644cfb7cd59159991c155853     0
# 69   64dbb4910a8681f0894018a6     0
# 73   64e715bc95096203239a7f4f     0
# 75   64f1c2c4b0584f72dc5a82d4     0
# 88   6511b108072b295da7259be3     0
# 121  654b7e7a657d7b5cc1bfc860     0
# 125  6550ee44cfc63e5d8cc5c53b     0
# 129  655100170b1d905d740c5681     0
# 143  655acf362f601f5d5811f9ab     0
# 144  655b64d01d10925cadc844f1     0
# 180  657565d80dae42a870116a2a     0
# 199  657ef951fd24e00fdfa6c626     0
# 202  657f0ec616bda1111b6824f1     0
# 204  657f325c0f31810f9fee2fd7     0
# 217  65893bc55bb0ef185d5bc8b8     0
# 226  65918a834a9c665e92a22c6c     0
# 229  659197db6dfa1e5f23ea0caf     0
# 253  65a174ec158dd81eed45a320     0
# 276  65b928ea97237aa365ccb0a1     0
# 326  65d200bf7fca888ab8bbdab9     0
# 350  65f43fc65482b460b5e74119     0
# 355  65fbf2970160d51b03229a90     0

# %%
df6[df6['pred']==0].describe()
# Out:
#           accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# count  1720.000000   1720.000000     1720.000000      1720.000000
# mean     58.121024     12.968602        3.195799        83.835599
# std      37.446076     12.039840        5.263671        14.035146
# min       0.000000      0.000000        0.000000        33.333333
# 25%       0.000000      0.000000        0.000000        73.333333
# 50%      73.684211     12.158167        0.000000        83.870968
# 75%      87.500000     21.875000        5.555556       100.000000
# max     100.000000     55.555556       50.000000       100.000000
#
#        moderateCorrect1  moderateIncorrect1  moderateUnanswered1  \
# count       1720.000000         1720.000000          1720.000000
# mean          10.901310            3.324177            85.774512
# std           10.050577            4.620953            12.139674
# min            0.000000            0.000000            42.857143
# ...

# %%
df6[df6['pred']==1].describe()
# Out:
#           accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# count  2313.000000   2310.000000     2310.000000      2310.000000
# mean     62.251480     54.498377       29.416031        16.085593
# std       9.848226     17.981250       16.625187        13.485434
# min      10.000000      0.000000        0.000000         0.000000
# 25%      57.575758     45.454545       20.000000         0.000000
# 50%      64.406780     54.545455       26.666667        15.384615
# 75%      69.230769     66.666667       37.500000        25.000000
# max      91.666667    100.000000      100.000000       100.000000
#
#        moderateCorrect1  moderateIncorrect1  moderateUnanswered1  \
# count       2312.000000         2312.000000          2312.000000
# mean          47.813143           29.284559            22.902298
# std           15.031425           13.475369            14.626463
# min            0.000000            0.000000             0.000000
# ...

# %%
df6[df6['pred']==2].describe()
# Out:
#           accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# count  6828.000000   6826.000000     6826.000000      6826.000000
# mean     83.648162     68.238646       10.899958        20.861397
# std       6.360236     10.846365        7.138904         9.724255
# min      64.285714      0.000000        0.000000         0.000000
# 25%      79.032258     61.111111        6.060606        14.705882
# 50%      83.333333     68.421053       10.000000        20.588235
# 75%      88.235294     75.000000       15.625000        26.666667
# max     100.000000    100.000000       58.333333       100.000000
#
#        moderateCorrect1  moderateIncorrect1  moderateUnanswered1  \
# count       6821.000000         6821.000000          6821.000000
# mean          56.159220           11.616032            32.224748
# std           10.392795            6.676994            10.338221
# min            0.000000            0.000000             0.000000
# ...

# %%
df6[df6['pred']==3].describe()
# Out:
#           accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# count  2634.000000   2622.000000     2622.000000      2622.000000
# mean     85.490384     82.776271       11.026711         6.197018
# std       7.459827     12.801557       10.954846         8.516172
# min      59.090909     33.333333        0.000000         0.000000
# 25%      80.000000     75.000000        0.000000         0.000000
# 50%      85.714286     83.333333        9.523810         0.000000
# 75%      90.178571     91.666667       16.666667        11.111111
# max     100.000000    100.000000       66.666667        66.666667
#
#        moderateCorrect1  moderateIncorrect1  moderateUnanswered1  \
# count       2634.000000         2634.000000          2634.000000
# mean          76.175589           13.809933            10.014478
# std           13.452174           11.219755            10.593669
# min           25.000000            0.000000             0.000000
# ...

# %%
df6[df6['pred']==4].describe()
# Out:
#           accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# count  2868.000000   2868.000000     2868.000000      2868.000000
# mean     74.332292     45.328716       13.939036        40.732247
# std      10.422349     12.819318        9.045019        13.598579
# min      12.500000      0.000000        0.000000         0.000000
# 25%      68.421053     38.235294        7.142857        32.258065
# 50%      74.509804     46.666667       13.333333        40.000000
# 75%      81.250000     53.333333       19.705882        49.471831
# max     100.000000    100.000000       66.666667       100.000000
#
#        moderateCorrect1  moderateIncorrect1  moderateUnanswered1  \
# count       2867.000000         2867.000000          2867.000000
# mean          36.004498           12.820713            51.174789
# std           10.458227            7.444353            11.306689
# min            0.000000            0.000000             0.000000
# ...

# %%
df6=df6.merge(df6_1_1,how='left',left_on='userId',right_on='userId')

# %%
df6_1_1_1=df6.groupby('userId').describe()

# %%
df6_1_1_1.head()
# Out:
#                           (accuracy, count)  (accuracy, mean)  \
# userId
# 62a5b3562f2c8edf02cd8f28               16.0         79.833331
# 62fa83240a17af8738a2c04a               19.0         84.349733
# 63301744aae5e0e0ca524661               26.0         81.847625
# 6342b29ce77795e149e62052               82.0         83.329477
# 63542c772ef4ea103afdf799               65.0         78.968196
#
#                           (accuracy, std)  (accuracy, min)  (accuracy, 25%)  \
# userId
# 62a5b3562f2c8edf02cd8f28         7.941663        64.583333        75.303951
# 62fa83240a17af8738a2c04a        16.047210        25.000000        82.843137
# 63301744aae5e0e0ca524661         8.331969        64.000000        77.777778
# 6342b29ce77795e149e62052         8.322800        62.500000        78.622273
# 63542c772ef4ea103afdf799        13.585829        33.333333        73.214286
#
#                           (accuracy, 50%)  (accuracy, 75%)  (accuracy, max)  \
# userId
# ...

# %%
df6_1_1_1.columns=df6_1_1_1.columns.to_flat_index()

# %%
df6_1_1_2=df6_1_1_1[df6_1_1_1.iloc[:,-1]==0].iloc[:,[1,9,15,17,23,25,31,33,39,41,47,49,51,55,57,63,65,71,73,75,81,87,89,95,97,103]]

# %%
df6.head()
# Out:
#      accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# 0   71.428571     69.230769       23.076923         7.692308
# 1   86.956522     90.909091        9.090909         0.000000
# 2   85.000000     83.333333        8.333333         8.333333
# 3  100.000000      0.000000        0.000000       100.000000
# 4   62.500000     66.666667       22.222222        11.111111
#
#    moderateCorrect1  moderateIncorrect1  moderateUnanswered1  toughCorrect1  \
# 0         40.000000           30.000000            30.000000     100.000000
# 1         80.000000           10.000000            10.000000      50.000000
# 2         50.000000            0.000000            50.000000      16.666667
# 3         18.181818            0.000000            81.818182      12.500000
# 4         38.888889           38.888889            22.222222      66.666667
#
#    toughIncorrect1  toughUnanswered1  notVisited1  totalAttempted1  \
# 0         0.000000          0.000000     0.000000        84.000000
# ...

# %%
df6_1_1_2.head()
# Out:
#                           (accuracy, mean)  (easyCorrect1, mean)  \
# userId
# 63542c772ef4ea103afdf799         78.968196             42.046527
# 63e4ead10dd35d45089260b0         57.915288             26.045310
# 64273ab23bb1f2c5cdf1954e         58.294826             35.407988
# 644cfb7cd59159991c155853         42.227717             37.592362
# 64dbb4910a8681f0894018a6         78.144650             45.474903
#
#                           (easyCorrect1, max)  (easyIncorrect1, mean)  \
# userId
# 63542c772ef4ea103afdf799            83.333333                8.841028
# 63e4ead10dd35d45089260b0           100.000000               11.313334
# 64273ab23bb1f2c5cdf1954e            81.818182               13.594643
# 644cfb7cd59159991c155853            93.939394                6.088386
# 64dbb4910a8681f0894018a6           100.000000               12.101256
#
#                           (easyIncorrect1, max)  (easyUnanswered1, mean)  \
# userId
# ...

# %%
df6_1_1_3=df6_1_1_2.reset_index()

# %%
df6_1_1_3.head()
# Out:
#                      userId  (accuracy, mean)  (easyCorrect1, mean)  \
# 0  63542c772ef4ea103afdf799         78.968196             42.046527
# 1  63e4ead10dd35d45089260b0         57.915288             26.045310
# 2  64273ab23bb1f2c5cdf1954e         58.294826             35.407988
# 3  644cfb7cd59159991c155853         42.227717             37.592362
# 4  64dbb4910a8681f0894018a6         78.144650             45.474903
#
#    (easyCorrect1, max)  (easyIncorrect1, mean)  (easyIncorrect1, max)  \
# 0            83.333333                8.841028              45.454545
# 1           100.000000               11.313334              85.714286
# 2            81.818182               13.594643              35.483871
# 3            93.939394                6.088386              50.000000
# 4           100.000000               12.101256              60.000000
#
#    (easyUnanswered1, mean)  (easyUnanswered1, max)  (moderateCorrect1, mean)  \
# ...

# %%
df6_1_1_3=df6_1_1_3.merge(df6_1_1,how='left',left_on=['userId'],right_on='userId')

# %%
df6_1_1_3.head()
# Out:
#                      userId  (accuracy, mean)  (easyCorrect1, mean)  \
# 0  63542c772ef4ea103afdf799         78.968196             42.046527
# 1  63e4ead10dd35d45089260b0         57.915288             26.045310
# 2  64273ab23bb1f2c5cdf1954e         58.294826             35.407988
# 3  644cfb7cd59159991c155853         42.227717             37.592362
# 4  64dbb4910a8681f0894018a6         78.144650             45.474903
#
#    (easyCorrect1, max)  (easyIncorrect1, mean)  (easyIncorrect1, max)  \
# 0            83.333333                8.841028              45.454545
# 1           100.000000               11.313334              85.714286
# 2            81.818182               13.594643              35.483871
# 3            93.939394                6.088386              50.000000
# 4           100.000000               12.101256              60.000000
#
#    (easyUnanswered1, mean)  (easyUnanswered1, max)  (moderateCorrect1, mean)  \
# ...

# %%
df6_1.head()
# Out:
#      accuracy  easyCorrect1  easyIncorrect1  easyUnanswered1  \
# 0   71.428571     69.230769       23.076923         7.692308
# 1   86.956522     90.909091        9.090909         0.000000
# 2   85.000000     83.333333        8.333333         8.333333
# 3  100.000000      0.000000        0.000000       100.000000
# 4   62.500000     66.666667       22.222222        11.111111
#
#    moderateCorrect1  moderateIncorrect1  moderateUnanswered1  toughCorrect1  \
# 0         40.000000           30.000000            30.000000     100.000000
# 1         80.000000           10.000000            10.000000      50.000000
# 2         50.000000            0.000000            50.000000      16.666667
# 3         18.181818            0.000000            81.818182      12.500000
# 4         38.888889           38.888889            22.222222      66.666667
#
#    toughIncorrect1  toughUnanswered1  notVisited1  totalAttempted1  \
# 0         0.000000          0.000000     0.000000        84.000000
# ...

# %%
df6_1_1_3=df6_1_1_3.merge(df6_1[['userId','Percentile']],how='left',left_on='userId',right_on='userId')
df6_1_1_3.head()
# Out:
#                      userId  (accuracy, mean)  (easyCorrect1, mean)  \
# 0  63542c772ef4ea103afdf799         78.968196             42.046527
# 1  63542c772ef4ea103afdf799         78.968196             42.046527
# 2  63542c772ef4ea103afdf799         78.968196             42.046527
# 3  63542c772ef4ea103afdf799         78.968196             42.046527
# 4  63542c772ef4ea103afdf799         78.968196             42.046527
#
#    (easyCorrect1, max)  (easyIncorrect1, mean)  (easyIncorrect1, max)  \
# 0            83.333333                8.841028              45.454545
# 1            83.333333                8.841028              45.454545
# 2            83.333333                8.841028              45.454545
# 3            83.333333                8.841028              45.454545
# 4            83.333333                8.841028              45.454545
#
#    (easyUnanswered1, mean)  (easyUnanswered1, max)  (moderateCorrect1, mean)  \
# ...

# %%
df6_1_1_3=df6_1_1_3.groupby('userId').mean()

# %%
df6_1_1_3.head()
# Out:
#                           (accuracy, mean)  (easyCorrect1, mean)  \
# userId
# 63542c772ef4ea103afdf799         78.968196             42.046527
# 63e4ead10dd35d45089260b0         57.915288             26.045310
# 64273ab23bb1f2c5cdf1954e         58.294826             35.407988
# 644cfb7cd59159991c155853         42.227717             37.592362
# 64dbb4910a8681f0894018a6         78.144650             45.474903
#
#                           (easyCorrect1, max)  (easyIncorrect1, mean)  \
# userId
# 63542c772ef4ea103afdf799            83.333333                8.841028
# 63e4ead10dd35d45089260b0           100.000000               11.313334
# 64273ab23bb1f2c5cdf1954e            81.818182               13.594643
# 644cfb7cd59159991c155853            93.939394                6.088386
# 64dbb4910a8681f0894018a6           100.000000               12.101256
#
#                           (easyIncorrect1, max)  (easyUnanswered1, mean)  \
# userId
# ...

# %%
df6_1_1_3=df6_1_1_3.reset_index()
df6_1_1_3.head()
# Out:
#                      userId  (accuracy, mean)  (easyCorrect1, mean)  \
# 0  63542c772ef4ea103afdf799         78.968196             42.046527
# 1  63e4ead10dd35d45089260b0         57.915288             26.045310
# 2  64273ab23bb1f2c5cdf1954e         58.294826             35.407988
# 3  644cfb7cd59159991c155853         42.227717             37.592362
# 4  64dbb4910a8681f0894018a6         78.144650             45.474903
#
#    (easyCorrect1, max)  (easyIncorrect1, mean)  (easyIncorrect1, max)  \
# 0            83.333333                8.841028              45.454545
# 1           100.000000               11.313334              85.714286
# 2            81.818182               13.594643              35.483871
# 3            93.939394                6.088386              50.000000
# 4           100.000000               12.101256              60.000000
#
#    (easyUnanswered1, mean)  (easyUnanswered1, max)  (moderateCorrect1, mean)  \
# ...

# %%
df6_1_1_3.groupby('pred')['Percentile'].mean()
# Out:
# pred
# 0.0    99.333559
# Name: Percentile, dtype: float64

# %%
df6.head()
# Out:
#    <built-in method strip of str object at 0x2ac503570>  \
# 0                                          71.428571
# 1                                          86.956522
# 2                                          85.000000
# 3                                         100.000000
# 4                                          62.500000
#
#    <built-in method strip of str object at 0x112ae9080>  \
# 0                                          69.230769
# 1                                          90.909091
# 2                                          83.333333
# 3                                           0.000000
# 4                                          66.666667
#
#    <built-in method strip of str object at 0x112da7ad0>  \
# 0                                          23.076923
# 1                                           9.090909
# 2                                           8.333333
# 3                                           0.000000
# ...
