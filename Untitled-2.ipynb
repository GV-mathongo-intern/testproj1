# %%
import pandas as pd

# %%
import json
with open('strapi-admin-panel.detailed_analyses.json') as outf:
    df=json.load(outf)

# %%
df1=pd.DataFrame.from_dict(df)
df1.head()
# Out:
#                                     _id                                userId  \
# 0  {'$oid': '624ebb71efa6f45a6d23a8de'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 1  {'$oid': '624ebbedefa6f45a6d23aaf6'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 2  {'$oid': '624ebc97efa6f45a6d23ad0e'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 3  {'$oid': '624fdeaaefa6f45a6d23fc95'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 4  {'$oid': '624fdf26efa6f45a6d23ff60'}  {'$oid': '61f93b055fb129bffa8e69d7'}
#
#                                  testId  notVisited  \
# 0  {'$oid': '614dd5dda0282649c036e79e'}          70
# 1  {'$oid': '614dd5dda0282649c036e79f'}          75
# 2  {'$oid': '614dd5dda0282649c036e7a0'}          75
# 3  {'$oid': '624da37defa6f45a6d23a000'}         112
# 4  {'$oid': '624da37defa6f45a6d239fff'}         112
#
#                                             subjects  \
# 0  [{'painfulQuestions': [], 'missedConcepts': [{...
# 1  [{'painfulQuestions': [], 'missedConcepts': [{...
# ...

# %%
df1.shape
# Out:
# (181, 11)

# %%
df1['_id1']=df1['_id'].apply(lambda x:x.get('$oid'))
df1.head()
# Out:
#                                     _id                                userId  \
# 0  {'$oid': '624ebb71efa6f45a6d23a8de'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 1  {'$oid': '624ebbedefa6f45a6d23aaf6'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 2  {'$oid': '624ebc97efa6f45a6d23ad0e'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 3  {'$oid': '624fdeaaefa6f45a6d23fc95'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 4  {'$oid': '624fdf26efa6f45a6d23ff60'}  {'$oid': '61f93b055fb129bffa8e69d7'}
#
#                                  testId  notVisited  \
# 0  {'$oid': '614dd5dda0282649c036e79e'}          70
# 1  {'$oid': '614dd5dda0282649c036e79f'}          75
# 2  {'$oid': '614dd5dda0282649c036e7a0'}          75
# 3  {'$oid': '624da37defa6f45a6d23a000'}         112
# 4  {'$oid': '624da37defa6f45a6d239fff'}         112
#
#                                             subjects  \
# 0  [{'painfulQuestions': [], 'missedConcepts': [{...
# 1  [{'painfulQuestions': [], 'missedConcepts': [{...
# ...

# %%
df1['testid1']=df1['testId'].apply(lambda x:x.get('$oid'))
df1.head()
# Out:
#                                     _id                                userId  \
# 0  {'$oid': '624ebb71efa6f45a6d23a8de'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 1  {'$oid': '624ebbedefa6f45a6d23aaf6'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 2  {'$oid': '624ebc97efa6f45a6d23ad0e'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 3  {'$oid': '624fdeaaefa6f45a6d23fc95'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 4  {'$oid': '624fdf26efa6f45a6d23ff60'}  {'$oid': '61f93b055fb129bffa8e69d7'}
#
#                                  testId  notVisited  \
# 0  {'$oid': '614dd5dda0282649c036e79e'}          70
# 1  {'$oid': '614dd5dda0282649c036e79f'}          75
# 2  {'$oid': '614dd5dda0282649c036e7a0'}          75
# 3  {'$oid': '624da37defa6f45a6d23a000'}         112
# 4  {'$oid': '624da37defa6f45a6d239fff'}         112
#
#                                             subjects  \
# 0  [{'painfulQuestions': [], 'missedConcepts': [{...
# 1  [{'painfulQuestions': [], 'missedConcepts': [{...
# ...

# %%
df1['userid1']=df1['userId'].apply(lambda x:x.get('$oid'))
df1.head()
# Out:
#                                     _id                                userId  \
# 0  {'$oid': '624ebb71efa6f45a6d23a8de'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 1  {'$oid': '624ebbedefa6f45a6d23aaf6'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 2  {'$oid': '624ebc97efa6f45a6d23ad0e'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 3  {'$oid': '624fdeaaefa6f45a6d23fc95'}  {'$oid': '61f93b055fb129bffa8e69d7'}
# 4  {'$oid': '624fdf26efa6f45a6d23ff60'}  {'$oid': '61f93b055fb129bffa8e69d7'}
#
#                                  testId  notVisited  \
# 0  {'$oid': '614dd5dda0282649c036e79e'}          70
# 1  {'$oid': '614dd5dda0282649c036e79f'}          75
# 2  {'$oid': '614dd5dda0282649c036e7a0'}          75
# 3  {'$oid': '624da37defa6f45a6d23a000'}         112
# 4  {'$oid': '624da37defa6f45a6d239fff'}         112
#
#                                             subjects  \
# 0  [{'painfulQuestions': [], 'missedConcepts': [{...
# 1  [{'painfulQuestions': [], 'missedConcepts': [{...
# ...

# %%
df1.drop(['_id','userId','testId'],axis=1,inplace=True)
df1.head()
# Out:
#    notVisited                                           subjects  \
# 0          70  [{'painfulQuestions': [], 'missedConcepts': [{...
# 1          75  [{'painfulQuestions': [], 'missedConcepts': [{...
# 2          75  [{'painfulQuestions': [], 'missedConcepts': [{...
# 3         112  [{'painfulQuestions': [], 'missedConcepts': [{...
# 4         112  [{'painfulQuestions': [], 'missedConcepts': [{...
#
#                                            questions  \
# 0  [{'_id': {'$oid': '624ebb71efa6f45a6d23a8e2'},...
# 1  [{'_id': {'$oid': '624ebbedefa6f45a6d23aafa'},...
# 2  [{'_id': {'$oid': '624ebc97efa6f45a6d23ad12'},...
# 3  [{'_id': {'$oid': '624fdeaaefa6f45a6d23fc9b'},...
# 4  [{'_id': {'$oid': '624fdf26efa6f45a6d23ff66'},...
#
#                                           timeTravel  \
# 0  [{'_id': {'$oid': '624ebb71efa6f45a6d23a93c'},...
# 1  [{'_id': {'$oid': '624ebbedefa6f45a6d23ab54'},...
# 2  [{'_id': {'$oid': '624ebc97efa6f45a6d23ad6c'},...
# ...

# %%
df1['userid1'].nunique()
# Out:
# 24

# %%
df1['testid1'].nunique()
# Out:
# 129

# %%
a=df1['userid1'].drop_duplicates()

# %%
a
# Out:
# 0      61f93b055fb129bffa8e69d7
# 15     625e645cefa6f45a6d242f41
# 20     60767d3fa86f753846145692
# 28     60c859a597812656fc783f13
# 33     621e507604540e207ea790e1
# 72     6299e0341eaa0318fc98370e
# 90     61a63a836eae089191c6a71a
# 102    60e2b39e566129478143c10c
# 103    6336a211d650b0115cc1efaa
# 104    6336d2d9d650b0115cc1f2d4
# 105    62319d3d599b7f5f5ad80da4
# 112    637249920bff3e0fa490bf84
# 113    637366741d2350364f069a41
# 114    637c66d9a1931b2464a2f9cc
# 115    637efcb5986f5b98e56ae309
# 116    6387af02b050aae0b5713f8e
# 120    641ab7f84e6d46b1d397f3b3
# 121    641b51fd4e6d46b1d397f864
# 122    641b591b4e6d46b1d397f9f9
# 123    637249eb0bff3e0fa490c01a
# 126    664dec71ad0879bdb974a83a
# 129    66504499ad0879bdb974d6a0
# 130    66503de1ad0879bdb974d5d8
# 144    6651b837ad0879bdb9756b2d
# Name: userid1, dtype: object

# %%
df2=df1[df1['userid1']!='61f93b055fb129bffa8e69d7']

# %%
df2.shape
# Out:
# (166, 11)

# %%
df2['testid1'].nunique()
# Out:
# 115

# %%
df1[df1['testid1']=='6242de22af9dd6d0f5e0aee7']
# Out:
#     notVisited                                           subjects  \
# 21          21  [{'painfulQuestions': [], 'missedConcepts': [{...
# 22           9  [{'painfulQuestions': [], 'missedConcepts': [{...
#
#                                             questions  \
# 21  [{'_id': {'$oid': '62625a3324905064ba377454'},...
# 22  [{'_id': {'$oid': '6262ef0824905064ba378578'},...
#
#                                            timeTravel  \
# 21  [{'_id': {'$oid': '62625a3324905064ba377486'},...
# 22  [{'_id': {'$oid': '6262ef0824905064ba3785aa'},...
#
#                                       subjectMovement halfAnalysis  \
# 21  [{'_id': {'$oid': '62625a3324905064ba37748a'},...
# 22  [{'_id': {'$oid': '6262ef0824905064ba3785ae'},...
#
#    fullAnalysis  __v                      _id1                   testid1  \
# 21                 0  62625a3324905064ba37744f  6242de22af9dd6d0f5e0aee7
# 22                 0  6262ef0824905064ba378573  6242de22af9dd6d0f5e0aee7
#
# ...

# %%
df1['subjects'][0]
# Out:
# [{'painfulQuestions': [],
#   'missedConcepts': [{'$oid': '624e6069efa6f45a6d23a02b'},
#    {'$oid': '624e606aefa6f45a6d23a072'}],
#   '_id': {'$oid': '624ebb71efa6f45a6d23a8df'},
#   'subjectId': {'$oid': '607018ee404ae53194e73d90'},
#   'timeTaken': 21,
#   'totalMarkScored': 2,
#   'totalAttempted': 3,
#   'totalCorrect': 1,
#   'accuracy': 33.33333333333333,
#   'notVisited': 20,
#   'easyCorrect': 1,
#   'easyIncorrect': 0,
#   'easyUnanswered': 9,
#   'moderateCorrect': 0,
#   'moderateIncorrect': 1,
#   'moderateUnanswered': 10,
#   'toughCorrect': 0,
#   'toughIncorrect': 1,
#   'toughUnanswered': 8,
#   'perfectAttempts': 1,
#   'wastedAttempts': 2,
#   'overtimeAttempts': 0,
#   'confusedAttempts': 0},
#  {'painfulQuestions': [],
#   'missedConcepts': [{'$oid': '624e606befa6f45a6d23a0a5'},
#    {'$oid': '624e606cefa6f45a6d23a10a'}],
#   '_id': {'$oid': '624ebb71efa6f45a6d23a8e0'},
#   'subjectId': {'$oid': '607018ee404ae53194e73d91'},
#   'timeTaken': 8,
# ...

# %%
df1['questions'][0]
# Out:
# [{'_id': {'$oid': '624ebb71efa6f45a6d23a8e2'},
#   'questionId': {'$oid': '624e6069efa6f45a6d23a00d'},
#   'attemptOverview': '',
#   'isCorrect': False},
#  {'_id': {'$oid': '624ebb71efa6f45a6d23a8e3'},
#   'questionId': {'$oid': '624e6069efa6f45a6d23a012'},
#   'attemptOverview': '',
#   'isCorrect': False},
#  {'_id': {'$oid': '624ebb71efa6f45a6d23a8e4'},
#   'questionId': {'$oid': '624e6069efa6f45a6d23a017'},
#   'attemptOverview': '',
#   'isCorrect': False},
#  {'_id': {'$oid': '624ebb71efa6f45a6d23a8e5'},
#   'questionId': {'$oid': '624e6069efa6f45a6d23a01c'},
#   'attemptOverview': '',
#   'isCorrect': False},
#  {'_id': {'$oid': '624ebb71efa6f45a6d23a8e6'},
#   'questionId': {'$oid': '624e6069efa6f45a6d23a021'},
#   'attemptOverview': '',
#   'isCorrect': False},
#  {'_id': {'$oid': '624ebb71efa6f45a6d23a8e7'},
#   'questionId': {'$oid': '624e6069efa6f45a6d23a026'},
#   'attemptOverview': '',
#   'isCorrect': False},
#  {'_id': {'$oid': '624ebb71efa6f45a6d23a8e8'},
# ...

# %%
import json
with open('strapi-admin-panel.packs.json') as outf:
    df=json.load(outf)

# %%
df3=pd.DataFrame.from_dict(df)
df3.head()
# Out:
#                                     _id  source  \
# 0  {'$oid': '629c1aeaa267606d24fb7410'}  Quizrr
# 1  {'$oid': '62c5865f72c521b428635f4c'}  Quizrr
# 2  {'$oid': '62c5ca493f85644353f2e168'}  Quizrr
# 3  {'$oid': '637f61d27f1e1d0c28041282'}  Quizrr
# 4  {'$oid': '639767995dbf824f9314da54'}  Quizrr
#
#                                             subjects  \
# 0             [{'$oid': '607018ee404ae53194e73d92'}]
# 1  [{'$oid': '607018ee404ae53194e73d90'}, {'$oid'...
# 2  [{'$oid': '607018ee404ae53194e73d90'}, {'$oid'...
# 3  [{'$oid': '607018ee404ae53194e73d90'}, {'$oid'...
# 4  [{'$oid': '607018ee404ae53194e73d90'}, {'$oid'...
#
#                              examCategory  \
# 0  [{'$oid': '605dfae41236ab2b5487e9f6'}]
# 1  [{'$oid': '605dfae41236ab2b5487e9f6'}]
# 2  [{'$oid': '605dfae41236ab2b5487e9f6'}]
# 3  [{'$oid': '605dfae41236ab2b5487e9f6'}]
# 4  [{'$oid': '605dfae41236ab2b5487e9f6'}]
#
#                                targetYear  \
# 0  [{'$oid': '605df9e8d9afc62adc9656a6'}]
# ...

# %%
for col in df3.columns:
    print(col)
# Out:
# _id
# source
# subjects
# examCategory
# targetYear
# paymentLink
# studyMaterials
# price
# endDate
# discountedPrice
# slug
# startDate
# isLive
# version
# title
# icon
# tag
# description
# group
# published_at
# createdAt
# updatedAt
# __v
# created_by
# updated_by
# schedulePdf
# chapters
# tests
# concepts
# topics
# isVisible
# isPrimary
# timerType
# isV2AnalysisEnabled
# message
# liveSessions
# availableAddOns
# revisionNotes
# formulaSheets
# descriptionPoints
# highlightMe
# highlightMeText
# isComingSoon
# studentCountDetails
# order
# hideThisPackToWhoHavePurchasedPacks
# isReportingDisabled
# testVersions
# primaryTitle
# thumbnail
# secondaryPacks
# groupDetails
# targetYears
# detailsUrl
# isMarkForReviewAvailable
# isAccessBlocked
# accessBlockedMessage
# errorReportGoogleSheet
# category
# filtersAvailable
# isV2DashboardEnabled
# progressTrackVideo

# %%
df3['title'][1]
# Out:
# 'JEE Main 2023 Chapter-wise Test Series'

# %%
df4=df3[df3['title'].str.contains(r'(?i)(?=.*\bJEE\b)(?=.*FULL)')]

# %%
df4['title']
# Out:
# 2                 JEE Main 2023 Full Test Series
# 3        JEE Main 2023 Full Test Series (Sample)
# 5             JEE Advanced 2023 Full Test Series
# 12    JEE Main 2023 Full Test Series (Mini Pack)
# 14                JEE Main 2024 Full Test Series
# 21            JEE Advanced 2024 Full Test Series
# 24    JEE Main 2024 Full Test Series (Mini Pack)
# 32                JEE Main 2025 Full Test Series
# Name: title, dtype: object

# %%
df4.shape
# Out:
# (8, 62)

# %%
df4.reset_index(inplace=True,drop=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df4.reset_index(inplace=True,drop=True).head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
df4.shape
# Out:
# (8, 63)

# %%
df4['group'][0]
# Out:
# [{'tests': [{'$oid': '62c5cffe3a1ecea908c68050'},
#    {'$oid': '62c5cffe3a1ecea908c6804d'},
#    {'$oid': '62c5cffe3a1ecea908c68052'},
#    {'$oid': '62c5cffe3a1ecea908c68054'},
#    {'$oid': '62c5cffe3a1ecea908c68056'}],
#   '_id': {'$oid': '62c5cfd70f2642bb52f28772'},
#   'title': 'Part Tests'},
#  {'tests': [{'$oid': '62c5d046dc4ddbc8f155c99f'},
#    {'$oid': '62c5d046dc4ddbc8f155c9a1'},
#    {'$oid': '62c5d046dc4ddbc8f155c99b'},
#    {'$oid': '62c5d046dc4ddbc8f155c99d'},
#    {'$oid': '62c5d046dc4ddbc8f155c9aa'},
#    {'$oid': '62c5d046dc4ddbc8f155c9a6'},
#    {'$oid': '62c5d046dc4ddbc8f155c9ac'},
#    {'$oid': '62c5d046dc4ddbc8f155c9a8'},
#    {'$oid': '62c5d046dc4ddbc8f155c9ae'},
#    {'$oid': '62c5d046dc4ddbc8f155c9b0'},
#    {'$oid': '62c5d046dc4ddbc8f155c9b2'},
#    {'$oid': '62c5d046dc4ddbc8f155c9b4'},
#    {'$oid': '62c5d046dc4ddbc8f155c9b6'},
#    {'$oid': '62c5d046dc4ddbc8f155c9bc'},
#    {'$oid': '62c5d046dc4ddbc8f155c9b8'},
#    {'$oid': '62c5d046dc4ddbc8f155c9ba'},
# ...

# %%
df5=pd.DataFrame([(d.get('tests'),d.get('title')) for tup in df4.itertuples() for d in tup.group])
df5.head()
# Out:
#                                                    0                     1
# 0  [{'$oid': '62c5cffe3a1ecea908c68050'}, {'$oid'...            Part Tests
# 1  [{'$oid': '62c5d046dc4ddbc8f155c99f'}, {'$oid'...            Full Tests
# 2  [{'$oid': '63ea98a967de86a1a7466728'}, {'$oid'...  Previous Year Papers
# 3  [{'$oid': '637f63087f1e1d0c28041286'}, {'$oid'...  Previous Year Papers
# 4             [{'$oid': '63806e9b1a459792920d8f15'}]           Mock Papers

# %%
df6=df5[df5[1].str.contains(r'(?i)(?=.*\bFULL\b)')]
df6.head()
# Out:
#                                                     0           1
# 1   [{'$oid': '62c5d046dc4ddbc8f155c99f'}, {'$oid'...  Full Tests
# 6   [{'$oid': '6398a0c8d1c0932861332e1b'}, {'$oid'...  Full Tests
# 9   [{'$oid': '641588b7ba53754de28c892f'}, {'$oid'...  Full Tests
# 14  [{'$oid': '64d49861418e53aaa05bb4f5'}, {'$oid'...  Full Tests
# 16  [{'$oid': '65b21c7cacca0541e9d39075'}, {'$oid'...  Full Tests

# %%
df6.rename(columns={0:'testids'},inplace=True)
# Out:
# /var/folders/vr/2kzmkbl5167_gtmslwch1dtw0000gn/T/ipykernel_61184/996426645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6.rename(columns={0:'testids'},inplace=True)

# %%
df6.reset_index(inplace=True,drop=True)

# %%
a=[]
for tup in df6.itertuples():
    for d in tup.testids:
        a.append(d.get('$oid'))

# %%
a[3]
# Out:
# '62c5d046dc4ddbc8f155c99d'

# %%
df6['testids'][0]
# Out:
# [{'$oid': '62c5d046dc4ddbc8f155c99f'},
#  {'$oid': '62c5d046dc4ddbc8f155c9a1'},
#  {'$oid': '62c5d046dc4ddbc8f155c99b'},
#  {'$oid': '62c5d046dc4ddbc8f155c99d'},
#  {'$oid': '62c5d046dc4ddbc8f155c9aa'},
#  {'$oid': '62c5d046dc4ddbc8f155c9a6'},
#  {'$oid': '62c5d046dc4ddbc8f155c9ac'},
#  {'$oid': '62c5d046dc4ddbc8f155c9a8'},
#  {'$oid': '62c5d046dc4ddbc8f155c9ae'},
#  {'$oid': '62c5d046dc4ddbc8f155c9b0'},
#  {'$oid': '62c5d046dc4ddbc8f155c9b2'},
#  {'$oid': '62c5d046dc4ddbc8f155c9b4'},
#  {'$oid': '62c5d046dc4ddbc8f155c9b6'},
#  {'$oid': '62c5d046dc4ddbc8f155c9bc'},
#  {'$oid': '62c5d046dc4ddbc8f155c9b8'},
#  {'$oid': '62c5d046dc4ddbc8f155c9ba'},
#  {'$oid': '62c5d046dc4ddbc8f155c9c0'},
#  {'$oid': '62c5d046dc4ddbc8f155c9c2'},
#  {'$oid': '62c5d046dc4ddbc8f155c9be'},
#  {'$oid': '62c5d046dc4ddbc8f155c9c6'},
#  {'$oid': '62c5d046dc4ddbc8f155c9c4'},
#  {'$oid': '62c5d046dc4ddbc8f155c9c8'},
#  {'$oid': '62c5d046dc4ddbc8f155c9cc'},
#  {'$oid': '62c5d046dc4ddbc8f155c9ce'},
# ...

# %%
len(a)
# Out:
# 168

# %%
b=set(a)
a=list(b)
len(a)
# Out:
# 168

# %%
with open('yfile.txt', 'w') as f:
    for l in a:
        f.write(f"{{testId:ObjectId('{l}')}}, ")

# %%
df1.head()
# Out:
#    notVisited                                           subjects  \
# 0          70  [{'painfulQuestions': [], 'missedConcepts': [{...
# 1          75  [{'painfulQuestions': [], 'missedConcepts': [{...
# 2          75  [{'painfulQuestions': [], 'missedConcepts': [{...
# 3         112  [{'painfulQuestions': [], 'missedConcepts': [{...
# 4         112  [{'painfulQuestions': [], 'missedConcepts': [{...
#
#                                            questions  \
# 0  [{'_id': {'$oid': '624ebb71efa6f45a6d23a8e2'},...
# 1  [{'_id': {'$oid': '624ebbedefa6f45a6d23aafa'},...
# 2  [{'_id': {'$oid': '624ebc97efa6f45a6d23ad12'},...
# 3  [{'_id': {'$oid': '624fdeaaefa6f45a6d23fc9b'},...
# 4  [{'_id': {'$oid': '624fdf26efa6f45a6d23ff66'},...
#
#                                           timeTravel  \
# 0  [{'_id': {'$oid': '624ebb71efa6f45a6d23a93c'},...
# 1  [{'_id': {'$oid': '624ebbedefa6f45a6d23ab54'},...
# 2  [{'_id': {'$oid': '624ebc97efa6f45a6d23ad6c'},...
# ...

# %%
df1['subjects'][0]
# Out:
# [{'painfulQuestions': [],
#   'missedConcepts': [{'$oid': '624e6069efa6f45a6d23a02b'},
#    {'$oid': '624e606aefa6f45a6d23a072'}],
#   '_id': {'$oid': '624ebb71efa6f45a6d23a8df'},
#   'subjectId': {'$oid': '607018ee404ae53194e73d90'},
#   'timeTaken': 21,
#   'totalMarkScored': 2,
#   'totalAttempted': 3,
#   'totalCorrect': 1,
#   'accuracy': 33.33333333333333,
#   'notVisited': 20,
#   'easyCorrect': 1,
#   'easyIncorrect': 0,
#   'easyUnanswered': 9,
#   'moderateCorrect': 0,
#   'moderateIncorrect': 1,
#   'moderateUnanswered': 10,
#   'toughCorrect': 0,
#   'toughIncorrect': 1,
#   'toughUnanswered': 8,
#   'perfectAttempts': 1,
#   'wastedAttempts': 2,
#   'overtimeAttempts': 0,
#   'confusedAttempts': 0},
#  {'painfulQuestions': [],
#   'missedConcepts': [{'$oid': '624e606befa6f45a6d23a0a5'},
#    {'$oid': '624e606cefa6f45a6d23a10a'}],
#   '_id': {'$oid': '624ebb71efa6f45a6d23a8e0'},
#   'subjectId': {'$oid': '607018ee404ae53194e73d91'},
#   'timeTaken': 8,
# ...

# %%
for row in df1.head().itertuples():
    print(row)
# Out:
# Pandas(Index=0, notVisited=70, subjects=[{'painfulQuestions': [], 'missedConcepts': [{'$oid': '624e6069efa6f45a6d23a02b'}, {'$oid': '624e606aefa6f45a6d23a072'}], '_id': {'$oid': '624ebb71efa6f45a6d23a8df'}, 'subjectId': {'$oid': '607018ee404ae53194e73d90'}, 'timeTaken': 21, 'totalMarkScored': 2, 'totalAttempted': 3, 'totalCorrect': 1, 'accuracy': 33.33333333333333, 'notVisited': 20, 'easyCorrect': 1, 'easyIncorrect': 0, 'easyUnanswered': 9, 'moderateCorrect': 0, 'moderateIncorrect': 1, 'moderateUnanswered': 10, 'toughCorrect': 0, 'toughIncorrect': 1, 'toughUnanswered': 8, 'perfectAttempts': 1, 'wastedAttempts': 2, 'overtimeAttempts': 0, 'confusedAttempts': 0}, {'painfulQuestions': [], 'missedConcepts': [{'$oid': '624e606befa6f45a6d23a0a5'}, {'$oid': '624e606cefa6f45a6d23a10a'}], '_id': {'$oid': '624ebb71efa6f45a6d23a8e0'}, 'subjectId': {'$oid': '607018ee404ae53194e73d91'}, 'timeTaken': 8, 'totalMarkScored': 2, 'totalAttempted': 3, 'totalCorrect': 1, 'accuracy': 33.33333333333333, 'no
# ...

# %%
df7=pd.DataFrame([tuple(list(d.values()))+(tup._9,) for tup in df1.itertuples() for d in tup.subjects])

# %%
df7.head()
# Out:
#    0                                                  1   \
# 0  []  [{'$oid': '624e6069efa6f45a6d23a02b'}, {'$oid'...
# 1  []  [{'$oid': '624e606befa6f45a6d23a0a5'}, {'$oid'...
# 2  []  [{'$oid': '624e606defa6f45a6d23a13d'}, {'$oid'...
# 3  []  [{'$oid': '624e6082efa6f45a6d23a1de'}, {'$oid'...
# 4  []  [{'$oid': '624e6084efa6f45a6d23a276'}, {'$oid'...
#
#                                      2                                     3   \
# 0  {'$oid': '624ebb71efa6f45a6d23a8df'}  {'$oid': '607018ee404ae53194e73d90'}
# 1  {'$oid': '624ebb71efa6f45a6d23a8e0'}  {'$oid': '607018ee404ae53194e73d91'}
# 2  {'$oid': '624ebb71efa6f45a6d23a8e1'}  {'$oid': '607018ee404ae53194e73d92'}
# 3  {'$oid': '624ebbedefa6f45a6d23aaf7'}  {'$oid': '607018ee404ae53194e73d90'}
# 4  {'$oid': '624ebbedefa6f45a6d23aaf8'}  {'$oid': '607018ee404ae53194e73d91'}
#
#    4    5   6   7          8   9   ...  14  15  16  17  18  19  20  21  22  \
# ...

# %%
print(list(df1['subjects'][0][0].keys()))
# Out:
# ['painfulQuestions', 'missedConcepts', '_id', 'subjectId', 'timeTaken', 'totalMarkScored', 'totalAttempted', 'totalCorrect', 'accuracy', 'notVisited', 'easyCorrect', 'easyIncorrect', 'easyUnanswered', 'moderateCorrect', 'moderateIncorrect', 'moderateUnanswered', 'toughCorrect', 'toughIncorrect', 'toughUnanswered', 'perfectAttempts', 'wastedAttempts', 'overtimeAttempts', 'confusedAttempts']

# %%
df7.columns=list(df1['subjects'][0][0].keys())+['id1']
df7.head()
# Out:
#   painfulQuestions                                     missedConcepts  \
# 0               []  [{'$oid': '624e6069efa6f45a6d23a02b'}, {'$oid'...
# 1               []  [{'$oid': '624e606befa6f45a6d23a0a5'}, {'$oid'...
# 2               []  [{'$oid': '624e606defa6f45a6d23a13d'}, {'$oid'...
# 3               []  [{'$oid': '624e6082efa6f45a6d23a1de'}, {'$oid'...
# 4               []  [{'$oid': '624e6084efa6f45a6d23a276'}, {'$oid'...
#
#                                     _id                             subjectId  \
# 0  {'$oid': '624ebb71efa6f45a6d23a8df'}  {'$oid': '607018ee404ae53194e73d90'}
# 1  {'$oid': '624ebb71efa6f45a6d23a8e0'}  {'$oid': '607018ee404ae53194e73d91'}
# 2  {'$oid': '624ebb71efa6f45a6d23a8e1'}  {'$oid': '607018ee404ae53194e73d92'}
# 3  {'$oid': '624ebbedefa6f45a6d23aaf7'}  {'$oid': '607018ee404ae53194e73d90'}
# 4  {'$oid': '624ebbedefa6f45a6d23aaf8'}  {'$oid': '607018ee404ae53194e73d91'}
#
#    timeTaken  totalMarkScored  totalAttempted  totalCorrect   accuracy  \
# ...

# %%
import pip
# %pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 566.3 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 3.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 755.9 kB/s eta 0:00:0000:0100:02
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached contourpy-1.2.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-10.3.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.2 kB)
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 3.6 MB/s eta 0:00:0000:0100:01
# Using cached contourpy-1.2.1-cp39-cp39-macosx_11_0_arm64.whl (244 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 1.6 MB/s eta 0:00:0000:0100:01
# ...
